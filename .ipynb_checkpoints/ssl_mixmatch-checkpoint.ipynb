# %%
import numpy as np
import pandas as pd
import torch
import json
import matplotlib.pyplot as plt
import sklearn
from sklearn.preprocessing import StandardScaler, MinMaxScaler, Normalizer
from sklearn.cluster import KMeans
from sklearn.model_selection import KFold
import scipy

import torch.nn.functional as F
from torch.utils.data import TensorDataset, DataLoader

from torch import nn
import torch.nn.functional as F
from torch.utils.tensorboard import SummaryWriter

from sklearn.cluster import KMeans

import seaborn as sns

from torcheval.metrics.functional import r2_score

# %% [markdown]
# # The main idea is to generate pseudo-labels (aka guessed labels) to computate both Labeled abd Unlabeled losses

# %% [markdown]
# ### Weights that describes distribution of data in cells (Gaussian like)

# %%
def get_weigths(dataset):
    weights = []
    for batches in dataset:
        batch_weights = []
        for batch in batches:
            target_weights = []
            for y in batch:
                # where it belongs
                for j in range(len(bin_edges)-1):
                    if y >= bin_edges[j] and y <= bin_edges[j+1]:
                        target_weights.append(
                            error_weights[j]
                        )
            batch_weights.append(target_weights)
        weights.append(batch_weights)
    weights = np.array(weights)
    weights = torch.from_numpy(weights)
    # weights = weights.to(device)
    return weights
# print(yhat_loss.shape)

# %%
device = (
    "cuda"
    if torch.cuda.is_available()
    else "cpu"
)

# %% [markdown]
# ## Making training-testing tensor datasets under CV split

# %%
with open("core_parts.json", "r") as f:
    core_parts = json.load(f)

# %%
cores_l = pd.read_excel("input.xlsx", sheet_name="no_burnup")
cores_u = pd.read_excel("burnup_only.xlsx", index_col=0)

# %%
fuel_types = cores_l.loc[0, core_parts["fuel_type"]["ALL_CELLS"]].to_numpy()

# %%
cores_l.loc[:, core_parts["left"]["ALL_CELLS"]] = fuel_types - cores_l.loc[:, core_parts["burnup"]["ALL_CELLS"]].to_numpy()
cores_u.loc[:, core_parts["left"]["ALL_CELLS"]] = fuel_types - cores_u.loc[:, core_parts["burnup"]["ALL_CELLS"]].to_numpy()

# %%
cores_u.loc[:, core_parts["coef"]["ALL_CELLS"]] = None

# %% [markdown]
# ### Shuffle dataframes before tensorizing

# %%
cores_l = cores_l.sample(frac=1)
cores_u = cores_u.sample(frac=1)

# %%
cores_l_Xtofit = cores_l.loc[:, 
    [
        *core_parts["burnup"]["ALL_CELLS"],
        # *core_parts["left"]["ALL_CELLS"]
    ]
]
cores_l_ytofit = cores_l.loc[:, 
    [
        *core_parts["coef"]["ALL_CELLS"]
    ]
]

# %%
mmsX = MinMaxScaler(feature_range=(0,1))
mmsX.fit(cores_l_Xtofit)

mmsy = MinMaxScaler(feature_range=(0,1))
mmsy.fit(cores_l_ytofit)
# Out:
# MinMaxScaler()

# %%
cores_l = cores_l.iloc[:80, :]

# %%
cores_u.shape, cores_l.shape
# Out:
# ((12000, 60), (80, 82))

# %% [markdown]
# ### Dataset formation

# %%
Xl = cores_l.loc[:, 
    [
        *core_parts["burnup"]["ALL_CELLS"],
        # *core_parts["left"]["ALL_CELLS"]
    ]
]
yl = cores_l.loc[:, core_parts["coef"]["ALL_CELLS"]]

# %%
Xu = cores_u.loc[:, 
    [
        *core_parts["burnup"]["ALL_CELLS"],
        # *core_parts["left"]["ALL_CELLS"]
    ]
]
yu = cores_u.loc[:, core_parts["coef"]["ALL_CELLS"]]

# %%
Xl = mmsX.transform(Xl)
Xu = mmsX.transform(Xu)

yl = mmsy.transform(yl)

# %% [markdown]
# ### CV split

# %%
ns = 5
kf = KFold(n_splits=ns)
train_size = int(len(Xl) * (ns-1) / ns)
test_size = len(Xl) - train_size
splits_ind = list(kf.split(Xl))
train_size, test_size
# Out:
# (64, 16)

# %% [markdown]
# ### Started with making batches of tensors

# %%
# batch size of labeled data
lbatch = 8
# test set tensor
tbatch = 8

# unlabeled batch size and U to L ratio
cores_l_taken = train_size
cr = 32 * cores_l_taken
print(cr)
RUL = f"{cr}_{cores_l_taken}"

Xu_cr = Xu[:cr]
yu_cr = yu[:cr]

cv_datasets = []
for (train, test) in splits_ind[:ns-3]:
    Xyl_train = np.concatenate(
        ( Xl[train], yl[train] ),
        axis=1
    )
    Xylb_train = np.asarray(np.split(Xyl_train, len(Xyl_train)/lbatch))
    Xylb_train = np.asarray(Xylb_train).astype("float32")

    # tensor
    Xylb_train_tensor = torch.from_numpy(Xylb_train)

    Xyu_train = np.concatenate(
        (Xu_cr, yu_cr),
        axis=1
    )
    
    Xyub_train = np.asarray(np.split(Xyu_train, len(Xyl_train)/lbatch))
    Xyub_train = np.asarray(Xyub_train).astype("float32")
    
    Xyub_train_tensor = torch.from_numpy(Xyub_train)
    
    Xyl_test = np.concatenate(
        ( Xl[test], yl[test] ),
        axis=1
    )
    
    Xylb_test = np.asarray(np.split(Xyl_test, len(Xyl_test)/tbatch))
    Xylb_test = np.asarray(Xylb_test).astype("float32")
    # tensor
    Xylb_test_tensor = torch.from_numpy(Xylb_test)
    print(
        "train_set: ", Xylb_train_tensor.shape, 
        "test_set: ", Xylb_test_tensor.shape,
        "unlabeled_set: ", Xyub_train_tensor.shape
    )

    # do concat of L and U tensors
    Xy_train_tensor_cat = torch.cat(
        (Xylb_train_tensor, Xyub_train_tensor),
        dim=1
    )
    # shuffle batches
    Xy_train_tensor_cat = Xy_train_tensor_cat[
        torch.randperm(
            Xy_train_tensor_cat.shape[0] #index of batches
        )
    ]
    print(Xy_train_tensor_cat.shape)
    # train test tensors split
    inputs = 20
    X_train_tensor = Xy_train_tensor_cat[:, :, :inputs]
    X_test_tensor = Xylb_test_tensor[: , :, :inputs]
    
    y_train_tensor = Xy_train_tensor_cat[:, :, inputs:]
    y_test_tensor = Xylb_test_tensor[: , :, inputs:]

    # tensor dataset
    xy_train = TensorDataset(
        X_train_tensor,
        y_train_tensor
    )
    
    xy_test =  TensorDataset(
        X_test_tensor,
        y_test_tensor,
    )
    # to unpack and iterate over
    cv_datasets.append(
        (xy_train, xy_test)
    )
# Out:
# 2048
# train_set:  torch.Size([8, 8, 40]) test_set:  torch.Size([2, 8, 40]) unlabeled_set:  torch.Size([8, 256, 40])
# torch.Size([8, 264, 40])
# train_set:  torch.Size([8, 8, 40]) test_set:  torch.Size([2, 8, 40]) unlabeled_set:  torch.Size([8, 256, 40])
# torch.Size([8, 264, 40])

# %% [markdown]
# ## Model

# %%
class Model(nn.Module):
    def __init__(
        self
    ):
        super().__init__()
        
        # FNN
        self.predictor = nn.Sequential(
            nn.Linear(20, 64),
            nn.Linear(64, 1),
            nn.Sigmoid()
        )
    
    def forward(
        self,
        x        
    ):
        # predictor
        labels = self.predictor(x)
        return labels

def supervised_loss(
    target,
    pred,
    batch_size
):
    
    # yhat_loss = F.mse_loss(pred, target, reduction='sum') / batch_size
    yhat_loss = F.l1_loss(pred, target, reduction='none')

    # sum along rows and norm to batch size
    yhat_loss = yhat_loss.sum(dim=0) / batch_size
    
    # weigths on data
    # yhat_loss = yhat_loss*weights
    # wnorm = yhat_loss / yhat_loss.mean()
    # yhat_loss = yhat_loss*wnorm
    
    return yhat_loss

def get_similarity(a,b):
    sim = (a * b).sum()\
        /(
            torch.sqrt(
                (a**2).sum()
            )
            *
            torch.sqrt(
                (b**2).sum()
            )
        )
    return sim

def unsupervised_loss(
    target_mean,
    pred, 
    batch_size
):
    
    yhat_loss = 0
    yhat_losses = torch.tensor([])
    yhat_losses = yhat_losses.to(device)
    for i in range(pred.shape[0]):
        yhat_loss += F.l1_loss(pred[i], target_mean, reduction='none').sum(dim=0) / batch_size

        yhat_losses = torch.cat(
            (
                yhat_losses, F.l1_loss(pred[i], target_mean, reduction='none').sum(dim=0) / batch_size
            ),
            dim=0
        )
    # print(yhat_losses)

    yhat_loss = yhat_losses.mean()
    
    # yhat_loss /= pred.shape[0]
    
    # # yhat_loss = F.l1_loss(pred, target_mean, reduction='sum') / batch_size
    # yhat_loss = yhat_loss.mean()
    
    # yhat_loss = torch.sqrt(yhat_loss)
    # yhat_loss = -torch.log(yhat_loss)
    return yhat_loss

# %%
# yaug = 0.1

def get_noise(loc, scale, size, coef=0.01):
    # loc = loc.numpy()
    # scale = scale.numpy()
    # n = np.random.normal(loc=loc,scale=scale,size=size)
    tril = torch.diag_embed(scale)
    mvn = torch.distributions.MultivariateNormal(
        loc,
        scale_tril=tril
    )
    samples = mvn.sample(torch.Size([size]))
    res = ( samples - samples.mean(dim=0) )*coef
    
    return res

def train(
    model,
    dataset,
    L,
    u,
    optimizer,
    epoch_num,
):
        loss_epoch  = 0
        
        yl_epoch_loss = 0
        yu_epoch_loss = 0


        for nbatch, (X,y) in enumerate(dataset):
            # so it is shape of [32, 1]
            y = y[:, 0:1]
            
            y = y.to(device)
            # left only cell 7-6
            
            
            y_deep = torch.clone(y)

            Xl = X[:lbatch]
            Xu = X[lbatch:]
            # print(Xl.shape, Xu.shape)
            yl = y[:lbatch]
            yu = y[lbatch:]



            # aug_u
            Xaug_up = torch.tensor([])
            Xaug_um = torch.tensor([])
            Xaug_l = torch.tensor([])
            Xaug_u_mean = 0
            
            for _ in range(L):
                # aug l part
                mean_xl = Xl.mean(dim=0)
                std_xl = Xl.std(dim=0)
    
                noise_l = get_noise(
                    mean_xl,
                    std_xl,
                    len(Xl)
                )
                
                Xaug_l = torch.cat(
                    (
                        Xaug_l,
                        Xl + noise_l    
                    ),
                    dim=0
                )
                # print(nbatch, Xl[0])
                
                # aug u part
                mean_xu = Xu.mean(dim=0)
                std_xu = Xu.std(dim=0)
            
                noise_u = get_noise(
                    mean_xu,
                    std_xu,
                    len(Xu)
                )
                # print(mean_xu.shape, noise_u.shape)
                # add
                Xaug_up = torch.cat(
                    (
                        Xaug_up,
                        Xu + noise_u    
                    ),
                    dim=0
                )
                # print(Xu[0], noise_u[0], Xaug_up[0])
                # sub
                Xaug_um = torch.cat(
                    (
                        Xaug_um,
                        Xu - noise_u    
                    ),
                    dim=0
                )
                
            # Zero the gradients
            optimizer.zero_grad()

            # Xaug_l = Xaug_l.to(device)
            # NO aug for labeled data
            Xl = Xl.to(device)
            Xu = Xu.to(device)
            # Xaug_l = Xaug_l.to(device)
            
            Xaug_up = Xaug_up.to(device)
            Xaug_um = Xaug_um.to(device)
            
            labels_l = model(Xl)
            # labels_augl = model(Xaug_l)
            
            labels_up = model(Xaug_up)
            labels_um = model(Xaug_um)

            # lets say it is mean for u data
            labels_u_mean = model(Xu)

            loss_l = supervised_loss(
                yl,
                labels_l,
                Xl.shape[0]
            )
            yl_epoch_loss += loss_l.item()
  
            # aug unsupervised
            # chunks to average res
            labels_up_chunks = torch.reshape(
                labels_up, 
                (L, int(labels_up.shape[0]/L), labels_up.shape[-1])
            
            )
            # chunks to average res
            labels_um_chunks = torch.reshape(
                labels_um, 
                (L, int(labels_um.shape[0]/L), labels_um.shape[-1])
            
            )
            # labels_up_mean = labels_up_chunks.mean(dim=0)
            # labels_um_mean = labels_um_chunks.mean(dim=0)

            # labels_upm_mean = (labels_up_mean + labels_um_mean) / 2
            # print(labels_up_chunks.shape, labels_upm_mean.shape, labels_u_mean.shape)
            
            # comment out u mean
            # labels_u_mean = labels_u_chunks.mean(dim=0)
            loss_up = unsupervised_loss(
                labels_u_mean,
                labels_up_chunks,
                labels_u_mean.shape[0]
            )
            loss_um = unsupervised_loss(
                labels_u_mean,
                labels_um_chunks,
                labels_u_mean.shape[0]
            )
            yu_epoch_loss += (loss_up.item() + loss_um.item())
                
            # loss = loss_l + yaug*loss_yaugl + u*loss_u
            # l + u only
            loss = loss_l - u*(loss_up + loss_um)
            loss.backward()
            optimizer.step()
            
            loss_epoch += loss.item()
            
            
        loss_epoch = loss_epoch / len(dataset)
        yl_epoch_loss = yl_epoch_loss / len(dataset)
        yu_epoch_loss = yu_epoch_loss / len(dataset)
    
        print(
            yu_epoch_loss,
            yl_epoch_loss,
        )

        return loss_epoch, yl_epoch_loss, yu_epoch_loss

# %%
def test(
    model,
    dataset,
    L,
    epoch_num
):

        loss_epoch = 0
        r2_epoch = 0
        with torch.no_grad():
            for nbatch, (X,y) in enumerate(dataset):
                # so it is shape of [32, 1]
                y = y[:, 0:1]
                
                
                y = y.to(device)
                y_deep = torch.clone(y)

                X = X.to(device)
                
                labels = model(X)

                print(
                    "Test: ",
                    labels[0],
                    y[0]
                )

                loss = F.l1_loss(labels, y)
                loss_epoch += loss.item()
                
                r2 = r2_score(labels, y, multioutput="raw_values")
                r2_mean = r2.mean()
                print(r2)
                r2_epoch += r2_mean.item()
                
            
            loss_epoch = loss_epoch / len(dataset)
            r2_epoch = r2_epoch / len(dataset)

            return loss_epoch, r2_epoch

# %%
U = [0, 0.01, 0.1, 1]
# U = [2,4,6]
# U = [0.05, 0.1, 0.5]
# U = [4]
Ls = [1, 5, 10]
# Ls = [2]
for u in U:
    for L in Ls:
        # writer = SummaryWriter(f'ssl/akaMixMatch_negUloss_noise0.1_yl_yaug_yu_losses/RUL_{RUL}_L{L}_noweights_{u}_ucoef_{yaug}_yaugcoef')
        # writer = SummaryWriter(f'ssl/RUL_{RUL}_akaMixMatch_posUloss_noise0.01_yl_yaug_yu_losses/L{L}_noweights_{u}_ucoef_{yaug}_yaugcoef')
        # writer = SummaryWriter(f'ssl/RUL_{RUL}_akaMixMatch_negUloss_noise0.1_yl_yu_losses_20labels/L{L}_{u}_ucoef')
        writer = SummaryWriter(f'ssl/akaMixMatch_negUloss_noise0.05_yl_yu_losses_1label/Liter_lb{lbatch}/RUL_{RUL}/L{L}/{u}_ucoef_maxu')
        
        train_loss_cv, train_yl_loss_cv, train_yu_loss_cv = [], [], []
        test_loss_cv, test_r2_cv = [], []
        
        for (xy_train, xy_test) in cv_datasets:
            model = Model().to(device)
            adam = torch.optim.Adam(model.parameters())
            epoch = 160

            train_loss_epoches, train_yl_loss_epoches, train_yu_loss_epoches = [], [], []
            test_loss_epoches, test_r2_epoches = [], []
            for e in range(epoch):
                train_loss_epoch, train_yl_epoch_loss, train_yu_epoch_loss = train(
                    model,
                    xy_train,
                    L,
                    u,
                    adam,
                    e
                )
                train_loss_epoches.append(train_loss_epoch)
                train_yl_loss_epoches.append(train_yl_epoch_loss)
                train_yu_loss_epoches.append(train_yu_epoch_loss)
                
                test_loss_epoch, test_r2_epoch = test(
                    model,
                    xy_test,
                    L,
                    e
                )
                test_loss_epoches.append(test_loss_epoch)
                test_r2_epoches.append(test_r2_epoch)
            
            train_loss_cv.append(train_loss_epoches)
            train_yl_loss_cv.append(train_yl_loss_epoches)
            train_yu_loss_cv.append(train_yu_loss_epoches)
            
            test_loss_cv.append(test_loss_epoches)
            test_r2_cv.append(test_r2_epoches)
        
        # averaging results over cv
        train_loss_cv = np.asarray(train_loss_cv).mean(axis=0)
        train_yl_loss_cv = np.asarray(train_yl_loss_cv).mean(axis=0)
        train_yu_loss_cv = np.asarray(train_yu_loss_cv).mean(axis=0)
        
        test_loss_cv = np.asarray(test_loss_cv).mean(axis=0)
        test_r2_cv = np.asarray(test_r2_cv).mean(axis=0)
        
        # adding to writer
        for e in range(len(test_loss_cv)):
            # print(e)
            writer.add_scalar('Train/epoch_loss', train_loss_cv[e], global_step=e)
            writer.add_scalar('Train/yl_Loss', train_yl_loss_cv[e], global_step=e)
            writer.add_scalar('Train/yu_Loss', train_yu_loss_cv[e], global_step=e)
            
            
            writer.add_scalar('Test/y_loss', test_loss_cv[e], global_step=e)
            writer.add_scalar('Test/r2_mean', test_r2_cv[e], global_step=e)
        if u == 0:
            break
# Out:
# 0.00017136335372924805 14.356075048446655
# Test:  tensor([0.5300], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([-0.0923], device='cuda:0')
# 0.00015967432409524918 13.581096649169922
# Test:  tensor([0.5601], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([-0.0390], device='cuda:0')
# 0.0001885266974568367 13.373593091964722
# Test:  tensor([0.5768], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([-0.0386], device='cuda:0')
# 0.00018233247101306915 13.401378393173218
# Test:  tensor([0.5802], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([-0.0311], device='cuda:0')
# 0.00017036451026797295 13.364538669586182
# Test:  tensor([0.5728], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([-0.0040], device='cuda:0')
# 0.00016407808288931847 13.224645137786865
# Test:  tensor([0.5622], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.0225], device='cuda:0')
# 0.00018028263002634048 13.104312419891357
# Test:  tensor([0.5547], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.0418], device='cuda:0')
# 0.00019998429343104362 12.98316740989685
# Test:  tensor([0.5510], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.0584], device='cuda:0')
# 0.00018186820670962334 12.839520454406738
# Test:  tensor([0.5525], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.0735], device='cuda:0')
# 0.0001931111328303814 12.705574989318848
# Test:  tensor([0.5555], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.0866], device='cuda:0')
# 0.00021198391914367676 12.62235951423645
# Test:  tensor([0.5538], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.1022], device='cuda:0')
# 0.000196102075278759 12.537232875823975
# Test:  tensor([0.5482], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.1199], device='cuda:0')
# 0.00022090040147304535 12.420122861862183
# Test:  tensor([0.5449], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.1359], device='cuda:0')
# 0.0002550743520259857 12.305217027664185
# Test:  tensor([0.5431], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.1515], device='cuda:0')
# 0.00024177739396691322 12.191649675369263
# Test:  tensor([0.5418], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.1670], device='cuda:0')
# 0.0002880161628127098 12.09265422821045
# Test:  tensor([0.5374], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.1830], device='cuda:0')
# 0.0002949768677353859 11.981991291046143
# Test:  tensor([0.5340], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.1986], device='cuda:0')
# 0.0002942066639661789 11.85306167602539
# Test:  tensor([0.5332], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.2144], device='cuda:0')
# 0.00034541450440883636 11.741754055023193
# Test:  tensor([0.5308], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.2303], device='cuda:0')
# 0.00039887079037725925 11.631957054138184
# Test:  tensor([0.5252], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.2456], device='cuda:0')
# 0.00036676228046417236 11.506984949111938
# Test:  tensor([0.5220], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.2608], device='cuda:0')
# 0.0003892369568347931 11.38564944267273
# Test:  tensor([0.5205], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.2764], device='cuda:0')
# 0.00038000266067683697 11.26030158996582
# Test:  tensor([0.5201], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.2922], device='cuda:0')
# 0.0003968188539147377 11.138421058654785
# Test:  tensor([0.5181], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.3075], device='cuda:0')
# 0.0005047419108450413 11.014039039611816
# Test:  tensor([0.5149], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.3225], device='cuda:0')
# 0.0004352796822786331 10.879951000213623
# Test:  tensor([0.5131], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.3381], device='cuda:0')
# 0.0005428907461464405 10.741544485092163
# Test:  tensor([0.5124], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.3541], device='cuda:0')
# 0.0005676487926393747 10.606712818145752
# Test:  tensor([0.5097], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.3696], device='cuda:0')
# 0.0005491250194609165 10.460498809814453
# Test:  tensor([0.5082], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.3855], device='cuda:0')
# 0.0006313936319202185 10.310508251190186
# Test:  tensor([0.5073], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.4016], device='cuda:0')
# 0.0006577095482498407 10.167705535888672
# Test:  tensor([0.5041], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.4173], device='cuda:0')
# 0.0007139341905713081 10.01380968093872
# Test:  tensor([0.4992], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.4322], device='cuda:0')
# 0.0006188694387674332 9.85106086730957
# Test:  tensor([0.4959], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.4475], device='cuda:0')
# 0.0007427877280861139 9.683922529220581
# Test:  tensor([0.4935], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.4635], device='cuda:0')
# 0.0007558923680335283 9.512138366699219
# Test:  tensor([0.4918], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.4797], device='cuda:0')
# 0.0008524549193680286 9.335939168930054
# Test:  tensor([0.4902], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.4959], device='cuda:0')
# 0.0008244675118476152 9.155455827713013
# Test:  tensor([0.4887], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.5119], device='cuda:0')
# 0.0008585560135543346 8.979227304458618
# Test:  tensor([0.4851], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.5272], device='cuda:0')
# 0.0008219210430979729 8.800371646881104
# Test:  tensor([0.4786], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.5408], device='cuda:0')
# 0.000860866392031312 8.604889035224915
# Test:  tensor([0.4733], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.5531], device='cuda:0')
# 0.0010673534125089645 8.415839672088623
# Test:  tensor([0.4697], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.5654], device='cuda:0')
# 0.0009717075154185295 8.220401644706726
# Test:  tensor([0.4672], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.5779], device='cuda:0')
# 0.0010135243646800518 8.015592098236084
# Test:  tensor([0.4700], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.5932], device='cuda:0')
# 0.0010477867908775806 7.845486521720886
# Test:  tensor([0.4645], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.6033], device='cuda:0')
# 0.0010395327117294073 7.642084956169128
# Test:  tensor([0.4577], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.6115], device='cuda:0')
# 0.0013287339825183153 7.445860385894775
# Test:  tensor([0.4567], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.6242], device='cuda:0')
# 0.0011907571461051702 7.2611095905303955
# Test:  tensor([0.4530], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.6342], device='cuda:0')
# 0.0011892968323081732 7.052753210067749
# Test:  tensor([0.4437], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.6364], device='cuda:0')
# 0.0012658447958528996 6.9051913022994995
# Test:  tensor([0.4505], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.6566], device='cuda:0')
# 0.001226648222655058 6.709197163581848
# Test:  tensor([0.4497], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.6668], device='cuda:0')
# 0.0013744442258030176 6.490114092826843
# Test:  tensor([0.4432], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.6720], device='cuda:0')
# 0.0014574658125638962 6.304292917251587
# Test:  tensor([0.4419], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.6811], device='cuda:0')
# 0.0013959456700831652 6.119637608528137
# Test:  tensor([0.4367], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.6859], device='cuda:0')
# 0.00155679602175951 5.930216670036316
# Test:  tensor([0.4384], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.6973], device='cuda:0')
# 0.0015554064884781837 5.756369352340698
# Test:  tensor([0.4341], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.7025], device='cuda:0')
# 0.0015020964201539755 5.550722002983093
# Test:  tensor([0.4327], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.7101], device='cuda:0')
# 0.001658193999901414 5.363492846488953
# Test:  tensor([0.4296], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.7159], device='cuda:0')
# 0.0017333664000034332 5.170879006385803
# Test:  tensor([0.4281], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.7237], device='cuda:0')
# 0.0017193641979247332 5.014906167984009
# Test:  tensor([0.4238], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.7294], device='cuda:0')
# 0.0016818693839013577 4.875213205814362
# Test:  tensor([0.4285], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.7410], device='cuda:0')
# 0.0018114515114575624 4.742601275444031
# Test:  tensor([0.4164], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.7407], device='cuda:0')
# 0.002039060229435563 4.684483170509338
# Test:  tensor([0.4242], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.7547], device='cuda:0')
# 0.0017045957501977682 4.534800887107849
# Test:  tensor([0.4128], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.7547], device='cuda:0')
# 0.0021127143409103155 4.455429971218109
# Test:  tensor([0.4147], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.7647], device='cuda:0')
# 0.0017954078502953053 4.241801559925079
# Test:  tensor([0.4137], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.7723], device='cuda:0')
# 0.001965007744729519 4.139794111251831
# Test:  tensor([0.4163], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.7812], device='cuda:0')
# 0.0018720487132668495 4.012008786201477
# Test:  tensor([0.4125], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.7876], device='cuda:0')
# 0.0016649141907691956 3.9025838971138
# Test:  tensor([0.4069], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.7933], device='cuda:0')
# 0.0019002407789230347 3.773013472557068
# Test:  tensor([0.4144], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.8031], device='cuda:0')
# 0.0019939481280744076 3.718009114265442
# Test:  tensor([0.4005], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.8066], device='cuda:0')
# 0.001979513093829155 3.6211103796958923
# Test:  tensor([0.4185], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.8128], device='cuda:0')
# 0.0020671626552939415 3.7172285318374634
# Test:  tensor([0.3906], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.8124], device='cuda:0')
# 0.0019233650527894497 3.6677416563034058
# Test:  tensor([0.4024], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.8283], device='cuda:0')
# 0.00202350364997983 3.351421594619751
# Test:  tensor([0.4036], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.8343], device='cuda:0')
# 0.0021117310971021652 3.2668965458869934
# Test:  tensor([0.3910], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.8361], device='cuda:0')
# 0.002301821019500494 3.137556731700897
# Test:  tensor([0.4116], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.8386], device='cuda:0')
# 0.0019932647701352835 3.336315095424652
# Test:  tensor([0.3837], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.8433], device='cuda:0')
# 0.0019459854811429977 3.3864619731903076
# Test:  tensor([0.3884], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.8538], device='cuda:0')
# 0.0020855972543358803 2.9436219334602356
# Test:  tensor([0.3978], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.8594], device='cuda:0')
# 0.002039654878899455 2.9121950268745422
# Test:  tensor([0.3822], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.8616], device='cuda:0')
# 0.0019936547614634037 2.770063430070877
# Test:  tensor([0.3931], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.8683], device='cuda:0')
# 0.001942956354469061 2.7443016469478607
# Test:  tensor([0.3824], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.8724], device='cuda:0')
# 0.002258501946926117 2.681029587984085
# Test:  tensor([0.3862], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.8769], device='cuda:0')
# 0.0020529309986159205 2.634182631969452
# Test:  tensor([0.3812], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.8804], device='cuda:0')
# 0.0021436677780002356 2.557325541973114
# Test:  tensor([0.3786], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.8837], device='cuda:0')
# 0.00231066532433033 2.4812427759170532
# Test:  tensor([0.3784], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.8873], device='cuda:0')
# 0.0022206599824130535 2.4174658060073853
# Test:  tensor([0.3759], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.8906], device='cuda:0')
# 0.0024285787949338555 2.3712465465068817
# Test:  tensor([0.3725], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.8935], device='cuda:0')
# 0.0022067080717533827 2.363783538341522
# Test:  tensor([0.3765], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.8968], device='cuda:0')
# 0.0022888112580403686 2.2950283586978912
# Test:  tensor([0.3744], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.8999], device='cuda:0')
# 0.0020994534716010094 2.290222555398941
# Test:  tensor([0.3710], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.9026], device='cuda:0')
# 0.0024186988594010472 2.2293523848056793
# Test:  tensor([0.3689], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.9052], device='cuda:0')
# 0.002280284301377833 2.288099527359009
# Test:  tensor([0.3755], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.9071], device='cuda:0')
# 0.0021737224888056517 2.1980532109737396
# Test:  tensor([0.3705], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.9117], device='cuda:0')
# 0.0022272104397416115 2.119123190641403
# Test:  tensor([0.3671], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.9151], device='cuda:0')
# 0.00287062069401145 2.0843507051467896
# Test:  tensor([0.3621], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.9172], device='cuda:0')
# 0.0025596149498596787 2.170090436935425
# Test:  tensor([0.3691], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.9202], device='cuda:0')
# 0.002136137103661895 2.087741434574127
# Test:  tensor([0.3678], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.9233], device='cuda:0')
# 0.0023697251453995705 2.154447376728058
# Test:  tensor([0.3543], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.9248], device='cuda:0')
# 0.00253479415550828 2.11552757024765
# Test:  tensor([0.3643], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.9290], device='cuda:0')
# 0.002650332869961858 1.9932263493537903
# Test:  tensor([0.3584], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.9321], device='cuda:0')
# 0.0027250434504821897 1.965595781803131
# Test:  tensor([0.3542], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.9340], device='cuda:0')
# 0.0022629847517237067 1.982113629579544
# Test:  tensor([0.3547], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.9367], device='cuda:0')
# 0.002528494456782937 1.93448144197464
# Test:  tensor([0.3538], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.9389], device='cuda:0')
# 0.0022664222633466125 1.903278261423111
# Test:  tensor([0.3540], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.9408], device='cuda:0')
# 0.0024501169100403786 1.89975044131279
# Test:  tensor([0.3513], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.9423], device='cuda:0')
# 0.002235059975646436 1.8614826500415802
# Test:  tensor([0.3498], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.9434], device='cuda:0')
# 0.002268657204695046 1.8561725318431854
# Test:  tensor([0.3484], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.9444], device='cuda:0')
# 0.0023773014545440674 1.875788390636444
# Test:  tensor([0.3539], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.9457], device='cuda:0')
# 0.002417069859802723 1.882791817188263
# Test:  tensor([0.3492], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.9478], device='cuda:0')
# 0.002333044772967696 1.8112312257289886
# Test:  tensor([0.3479], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.9492], device='cuda:0')
# 0.002537101157940924 1.8196880221366882
# Test:  tensor([0.3478], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.9504], device='cuda:0')
# 0.0025773943634703755 1.7911584675312042
# Test:  tensor([0.3433], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.9511], device='cuda:0')
# 0.0024568455992266536 1.7640835046768188
# Test:  tensor([0.3392], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.9506], device='cuda:0')
# 0.0022305893944576383 1.7873114049434662
# Test:  tensor([0.3454], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.9531], device='cuda:0')
# 0.002462692675180733 1.7438381016254425
# Test:  tensor([0.3411], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.9539], device='cuda:0')
# 0.002590821706689894 1.7169744074344635
# Test:  tensor([0.3450], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.9548], device='cuda:0')
# 0.0026839955244213343 1.7382664680480957
# Test:  tensor([0.3420], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.9558], device='cuda:0')
# 0.0023512053303420544 1.702718734741211
# Test:  tensor([0.3378], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.9559], device='cuda:0')
# 0.002469105878844857 1.692282795906067
# Test:  tensor([0.3405], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.9574], device='cuda:0')
# 0.002268308773636818 1.6609027683734894
# Test:  tensor([0.3355], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.9577], device='cuda:0')
# 0.0022072334541007876 1.6518672704696655
# Test:  tensor([0.3403], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.9593], device='cuda:0')
# 0.0025296752573922276 1.6703900396823883
# Test:  tensor([0.3348], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.9598], device='cuda:0')
# 0.002639435464516282 1.6176339983940125
# Test:  tensor([0.3327], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.9598], device='cuda:0')
# 0.002744609722867608 1.6056541502475739
# Test:  tensor([0.3335], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.9611], device='cuda:0')
# 0.0027304906398057938 1.602974534034729
# Test:  tensor([0.3349], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.9618], device='cuda:0')
# 0.002394439186900854 1.5826610326766968
# Test:  tensor([0.3293], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.9612], device='cuda:0')
# 0.0023923413828015327 1.5668059885501862
# Test:  tensor([0.3315], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.9627], device='cuda:0')
# 0.0023235108237713575 1.6114807724952698
# Test:  tensor([0.3327], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.9634], device='cuda:0')
# 0.002813171362504363 1.597521424293518
# Test:  tensor([0.3263], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.9625], device='cuda:0')
# 0.0023036112543195486 1.565503478050232
# Test:  tensor([0.3244], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.9622], device='cuda:0')
# 0.002314591547474265 1.5535917580127716
# Test:  tensor([0.3280], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.9649], device='cuda:0')
# 0.002344797132536769 1.5553609728813171
# Test:  tensor([0.3300], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.9657], device='cuda:0')
# 0.0026712269755080342 1.5428182482719421
# Test:  tensor([0.3238], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.9648], device='cuda:0')
# 0.0024928171187639236 1.4900226891040802
# Test:  tensor([0.3244], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.9659], device='cuda:0')
# 0.0028084481600672007 1.481880247592926
# Test:  tensor([0.3268], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.9668], device='cuda:0')
# 0.0023762774653732777 1.4710779786109924
# Test:  tensor([0.3249], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.9668], device='cuda:0')
# 0.0023953536292538047 1.4666000753641129
# Test:  tensor([0.3232], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.9665], device='cuda:0')
# 0.002585070440545678 1.4339285343885422
# Test:  tensor([0.3208], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.9654], device='cuda:0')
# 0.0024641581112518907 1.4513598680496216
# Test:  tensor([0.3212], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.9662], device='cuda:0')
# 0.002398648066446185 1.4366831481456757
# Test:  tensor([0.3209], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.9667], device='cuda:0')
# 0.002565889386460185 1.4302187263965607
# Test:  tensor([0.3233], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.9678], device='cuda:0')
# 0.0025320941349491477 1.5207918286323547
# Test:  tensor([0.3202], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.9672], device='cuda:0')
# 0.002887174137867987 1.4486436545848846
# Test:  tensor([0.3180], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.9663], device='cuda:0')
# 0.002630924223922193 1.4258872270584106
# Test:  tensor([0.3206], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.9676], device='cuda:0')
# 0.0026714164996519685 1.4165083467960358
# Test:  tensor([0.3197], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.9674], device='cuda:0')
# 0.0026276292046532035 1.4023244678974152
# Test:  tensor([0.3147], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.9645], device='cuda:0')
# 0.0027183614438399673 1.497867226600647
# Test:  tensor([0.3147], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.9648], device='cuda:0')
# 0.0023295098217204213 1.4868038892745972
# Test:  tensor([0.3201], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.9682], device='cuda:0')
# 0.0025064556393772364 1.468079388141632
# Test:  tensor([0.3201], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.9684], device='cuda:0')
# 0.0027936925180256367 1.4108164012432098
# Test:  tensor([0.3196], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.9682], device='cuda:0')
# 0.0024278751807287335 1.4733507633209229
# Test:  tensor([0.3143], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.9647], device='cuda:0')
# 0.002811006153933704 1.4816595911979675
# Test:  tensor([0.3150], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.9650], device='cuda:0')
# 0.0022279968252405524 1.4936459958553314
# Test:  tensor([0.3226], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.9684], device='cuda:0')
# 0.002567248069681227 1.4845816493034363
# Test:  tensor([0.3192], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.9678], device='cuda:0')
# 0.0025684519205242395 1.4560931622982025
# Test:  tensor([0.3152], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.9657], device='cuda:0')
# 0.0027506198966875672 1.4068845212459564
# Test:  tensor([0.3199], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.9685], device='cuda:0')
# 0.0027827194426208735 1.4153082966804504
# Test:  tensor([0.3142], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.9659], device='cuda:0')
# 0.0024402077542617917 1.484627366065979
# Test:  tensor([0.3117], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.9642], device='cuda:0')
# 0.002464181976392865 1.5239766538143158
# Test:  tensor([0.3234], device='cuda:0') tensor([0.3250], device='cuda:0')
# tensor([0.9692], device='cuda:0')
# 0.00018959399312734604 13.626439809799194
# Test:  tensor([0.5803], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([-0.0390], device='cuda:0')
# 0.00020186789333820343 13.332569599151611
# Test:  tensor([0.5892], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([-0.0394], device='cuda:0')
# 0.00018462538719177246 13.170702457427979
# Test:  tensor([0.5890], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([-0.0252], device='cuda:0')
# 0.00018904870375990868 13.006996393203735
# Test:  tensor([0.5848], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([-0.0059], device='cuda:0')
# 0.00018495088443160057 12.852468252182007
# Test:  tensor([0.5807], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.0115], device='cuda:0')
# 0.0001655970700085163 12.718111991882324
# Test:  tensor([0.5787], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.0255], device='cuda:0')
# 0.00020918156951665878 12.6165292263031
# Test:  tensor([0.5829], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.0347], device='cuda:0')
# 0.00023821648210287094 12.4827299118042
# Test:  tensor([0.5877], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.0432], device='cuda:0')
# 0.00023685721680521965 12.341507911682129
# Test:  tensor([0.5900], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.0534], device='cuda:0')
# 0.00023286882787942886 12.200907468795776
# Test:  tensor([0.5900], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.0653], device='cuda:0')
# 0.0002504647709429264 12.063576459884644
# Test:  tensor([0.5907], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.0768], device='cuda:0')
# 0.0003032735548913479 11.938555002212524
# Test:  tensor([0.5947], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.0857], device='cuda:0')
# 0.0003330772742629051 11.801767110824585
# Test:  tensor([0.5968], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.0959], device='cuda:0')
# 0.0003344113938510418 11.648579597473145
# Test:  tensor([0.5964], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.1080], device='cuda:0')
# 0.0003485092893242836 11.50373888015747
# Test:  tensor([0.5966], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.1191], device='cuda:0')
# 0.00036810128949582577 11.372799396514893
# Test:  tensor([0.6001], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.1273], device='cuda:0')
# 0.0003924076445400715 11.22716498374939
# Test:  tensor([0.6065], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.1322], device='cuda:0')
# 0.000400422140955925 11.073997974395752
# Test:  tensor([0.6099], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.1401], device='cuda:0')
# 0.0004835010040551424 10.900996446609497
# Test:  tensor([0.6097], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.1520], device='cuda:0')
# 0.0005109340418130159 10.72594428062439
# Test:  tensor([0.6096], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.1634], device='cuda:0')
# 0.000515735475346446 10.578943490982056
# Test:  tensor([0.6146], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.1695], device='cuda:0')
# 0.0005283043719828129 10.426534652709961
# Test:  tensor([0.6181], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.1768], device='cuda:0')
# 0.0005748008843511343 10.250597953796387
# Test:  tensor([0.6176], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.1884], device='cuda:0')
# 0.000573539175093174 10.097074031829834
# Test:  tensor([0.6199], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.1967], device='cuda:0')
# 0.0005819422658532858 9.943650722503662
# Test:  tensor([0.6256], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.2010], device='cuda:0')
# 0.0006443951278924942 9.759925365447998
# Test:  tensor([0.6258], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.2120], device='cuda:0')
# 0.0007336568087339401 9.588039636611938
# Test:  tensor([0.6231], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.2252], device='cuda:0')
# 0.0006673384923487902 9.448685050010681
# Test:  tensor([0.6294], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.2307], device='cuda:0')
# 0.0006925377529114485 9.268579840660095
# Test:  tensor([0.6332], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.2386], device='cuda:0')
# 0.0007285955362021923 9.098114967346191
# Test:  tensor([0.6354], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.2486], device='cuda:0')
# 0.0007788140792399645 8.92241370677948
# Test:  tensor([0.6332], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.2616], device='cuda:0')
# 0.0008479990065097809 8.732155203819275
# Test:  tensor([0.6302], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.2724], device='cuda:0')
# 0.0008665111381560564 8.570721983909607
# Test:  tensor([0.6408], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.2796], device='cuda:0')
# 0.000981650548055768 8.388294339179993
# Test:  tensor([0.6447], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.2888], device='cuda:0')
# 0.0009460300207138062 8.192171692848206
# Test:  tensor([0.6445], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.2997], device='cuda:0')
# 0.0010113443713635206 8.002072930335999
# Test:  tensor([0.6434], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.3092], device='cuda:0')
# 0.00089880614541471 7.815236330032349
# Test:  tensor([0.6487], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.3191], device='cuda:0')
# 0.0009669533465057611 7.617532014846802
# Test:  tensor([0.6573], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.3280], device='cuda:0')
# 0.00110392807982862 7.427008152008057
# Test:  tensor([0.6592], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.3379], device='cuda:0')
# 0.0010965948458760977 7.222909927368164
# Test:  tensor([0.6620], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.3473], device='cuda:0')
# 0.0011110918130725622 7.024189352989197
# Test:  tensor([0.6639], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.3570], device='cuda:0')
# 0.0012326180003583431 6.840270042419434
# Test:  tensor([0.6643], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.3669], device='cuda:0')
# 0.0014064572751522064 6.6443997621536255
# Test:  tensor([0.6721], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.3794], device='cuda:0')
# 0.0013568131253123283 6.463028430938721
# Test:  tensor([0.6721], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.3906], device='cuda:0')
# 0.0013021903578191996 6.2652260065078735
# Test:  tensor([0.6800], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.4031], device='cuda:0')
# 0.0012254100292921066 6.075631141662598
# Test:  tensor([0.6799], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.4143], device='cuda:0')
# 0.0014948102179914713 5.898839712142944
# Test:  tensor([0.6906], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.4258], device='cuda:0')
# 0.0014224555343389511 5.706506967544556
# Test:  tensor([0.6851], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.4344], device='cuda:0')
# 0.0015535005368292332 5.607115030288696
# Test:  tensor([0.7034], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.4449], device='cuda:0')
# 0.0014348183758556843 5.462069988250732
# Test:  tensor([0.6893], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.4518], device='cuda:0')
# 0.001403709640726447 5.417722821235657
# Test:  tensor([0.7103], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.4665], device='cuda:0')
# 0.0015060673467814922 5.188519597053528
# Test:  tensor([0.7043], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.4778], device='cuda:0')
# 0.0015956165734678507 5.018642604351044
# Test:  tensor([0.7126], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.4884], device='cuda:0')
# 0.0016116411425173283 4.857525050640106
# Test:  tensor([0.7173], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.4994], device='cuda:0')
# 0.0015376463998109102 4.742576897144318
# Test:  tensor([0.7183], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.5114], device='cuda:0')
# 0.0016709407791495323 4.605616867542267
# Test:  tensor([0.7244], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.5225], device='cuda:0')
# 0.001671457663178444 4.499022364616394
# Test:  tensor([0.7235], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.5355], device='cuda:0')
# 0.0018984032794833183 4.371634006500244
# Test:  tensor([0.7273], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.5462], device='cuda:0')
# 0.0016231732442975044 4.257932662963867
# Test:  tensor([0.7280], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.5582], device='cuda:0')
# 0.001765700988471508 4.191646099090576
# Test:  tensor([0.7277], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.5686], device='cuda:0')
# 0.0016403809422627091 4.06821596622467
# Test:  tensor([0.7332], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.5775], device='cuda:0')
# 0.0018738270737230778 3.951102554798126
# Test:  tensor([0.7324], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.5879], device='cuda:0')
# 0.0020160822896286845 3.887430250644684
# Test:  tensor([0.7389], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.5966], device='cuda:0')
# 0.00172343198210001 3.804941475391388
# Test:  tensor([0.7408], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.6075], device='cuda:0')
# 0.0017208976205438375 3.7030171155929565
# Test:  tensor([0.7426], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.6198], device='cuda:0')
# 0.0018545339116826653 3.6216633915901184
# Test:  tensor([0.7445], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.6325], device='cuda:0')
# 0.001833162852562964 3.5414209961891174
# Test:  tensor([0.7443], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.6464], device='cuda:0')
# 0.0018108859658241272 3.501465618610382
# Test:  tensor([0.7431], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.6596], device='cuda:0')
# 0.001767856301739812 3.41114205121994
# Test:  tensor([0.7450], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.6706], device='cuda:0')
# 0.002017882652580738 3.32487028837204
# Test:  tensor([0.7475], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.6815], device='cuda:0')
# 0.001970179844647646 3.259058356285095
# Test:  tensor([0.7474], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.6916], device='cuda:0')
# 0.0018458447884768248 3.1953095197677612
# Test:  tensor([0.7520], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.7003], device='cuda:0')
# 0.0019201270770281553 3.1381389498710632
# Test:  tensor([0.7484], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.7095], device='cuda:0')
# 0.0021799379028379917 3.07584810256958
# Test:  tensor([0.7519], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.7179], device='cuda:0')
# 0.0017491718754172325 3.01178240776062
# Test:  tensor([0.7514], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.7264], device='cuda:0')
# 0.002003938890993595 2.943961203098297
# Test:  tensor([0.7523], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.7349], device='cuda:0')
# 0.0021718170028179884 2.905564069747925
# Test:  tensor([0.7571], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.7427], device='cuda:0')
# 0.002067978261038661 2.845574378967285
# Test:  tensor([0.7496], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.7531], device='cuda:0')
# 0.0018730886513367295 2.8104965686798096
# Test:  tensor([0.7556], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.7621], device='cuda:0')
# 0.0020210513612255454 2.72667533159256
# Test:  tensor([0.7604], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.7685], device='cuda:0')
# 0.002268432406708598 2.73283314704895
# Test:  tensor([0.7442], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.7726], device='cuda:0')
# 0.0019438080489635468 2.735876142978668
# Test:  tensor([0.7669], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.7802], device='cuda:0')
# 0.001974032958969474 2.7154939770698547
# Test:  tensor([0.7414], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.7819], device='cuda:0')
# 0.002229089615866542 2.7741071581840515
# Test:  tensor([0.7722], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.7906], device='cuda:0')
# 0.002138545853085816 2.7944701313972473
# Test:  tensor([0.7470], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.8031], device='cuda:0')
# 0.0021677901968359947 2.7896363139152527
# Test:  tensor([0.7610], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.8161], device='cuda:0')
# 0.002133073518052697 2.556834101676941
# Test:  tensor([0.7611], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.8226], device='cuda:0')
# 0.0021283685928210616 2.504166066646576
# Test:  tensor([0.7591], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.8280], device='cuda:0')
# 0.0023424625396728516 2.5679304003715515
# Test:  tensor([0.7647], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.8310], device='cuda:0')
# 0.002292877878062427 2.491572618484497
# Test:  tensor([0.7570], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.8356], device='cuda:0')
# 0.0020682283211499453 2.510443866252899
# Test:  tensor([0.7716], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.8326], device='cuda:0')
# 0.0023563087452203035 2.3174241185188293
# Test:  tensor([0.7559], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.8416], device='cuda:0')
# 0.002293853322044015 2.214507222175598
# Test:  tensor([0.7652], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.8454], device='cuda:0')
# 0.0025399127043783665 2.148071527481079
# Test:  tensor([0.7610], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.8500], device='cuda:0')
# 0.0022186232963576913 2.0911616683006287
# Test:  tensor([0.7634], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.8536], device='cuda:0')
# 0.0022544481325894594 2.074676960706711
# Test:  tensor([0.7624], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.8573], device='cuda:0')
# 0.0021884016459807754 2.0395997762680054
# Test:  tensor([0.7599], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.8601], device='cuda:0')
# 0.0022798546124249697 2.0127921402454376
# Test:  tensor([0.7666], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.8637], device='cuda:0')
# 0.0021968293003737926 1.976818710565567
# Test:  tensor([0.7633], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.8675], device='cuda:0')
# 0.002267906558699906 1.9960861802101135
# Test:  tensor([0.7630], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.8709], device='cuda:0')
# 0.0022860501194372773 1.9058949947357178
# Test:  tensor([0.7673], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.8742], device='cuda:0')
# 0.002176392823457718 1.8836877644062042
# Test:  tensor([0.7656], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.8771], device='cuda:0')
# 0.002443841425701976 1.9154959321022034
# Test:  tensor([0.7634], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.8791], device='cuda:0')
# 0.002498244517482817 1.8580117225646973
# Test:  tensor([0.7680], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.8817], device='cuda:0')
# 0.0022397300926968455 1.81094691157341
# Test:  tensor([0.7651], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.8845], device='cuda:0')
# 0.0023219973081722856 1.8307462632656097
# Test:  tensor([0.7625], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.8869], device='cuda:0')
# 0.0023559193359687924 1.8053204119205475
# Test:  tensor([0.7649], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.8902], device='cuda:0')
# 0.0024083241587504745 1.7746763229370117
# Test:  tensor([0.7629], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.8925], device='cuda:0')
# 0.0020540982950478792 1.7665125727653503
# Test:  tensor([0.7688], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.8949], device='cuda:0')
# 0.0024368574377149343 1.7541921138763428
# Test:  tensor([0.7633], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.8978], device='cuda:0')
# 0.0023472653701901436 1.7283263206481934
# Test:  tensor([0.7652], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.9000], device='cuda:0')
# 0.0021524428157135844 1.7091718316078186
# Test:  tensor([0.7697], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.9009], device='cuda:0')
# 0.002533005434088409 1.7126786410808563
# Test:  tensor([0.7641], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.9042], device='cuda:0')
# 0.0023413277231156826 1.7120553255081177
# Test:  tensor([0.7613], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.9057], device='cuda:0')
# 0.002280124695971608 1.7255698442459106
# Test:  tensor([0.7667], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.9082], device='cuda:0')
# 0.0022855583811178803 1.6320652663707733
# Test:  tensor([0.7624], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.9105], device='cuda:0')
# 0.002395830233581364 1.6673185527324677
# Test:  tensor([0.7664], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.9131], device='cuda:0')
# 0.002488219179213047 1.6219830811023712
# Test:  tensor([0.7720], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.9125], device='cuda:0')
# 0.0022478773025795817 1.7467387020587921
# Test:  tensor([0.7562], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.9129], device='cuda:0')
# 0.0023919499944895506 1.7363143563270569
# Test:  tensor([0.7732], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.9152], device='cuda:0')
# 0.002491968683898449 1.7198723256587982
# Test:  tensor([0.7588], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.9193], device='cuda:0')
# 0.002379502751864493 1.6428931951522827
# Test:  tensor([0.7654], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.9230], device='cuda:0')
# 0.0022015984868630767 1.5525228679180145
# Test:  tensor([0.7615], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.9240], device='cuda:0')
# 0.0023851162986829877 1.573672890663147
# Test:  tensor([0.7625], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.9256], device='cuda:0')
# 0.0022948868572711945 1.546673834323883
# Test:  tensor([0.7610], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.9267], device='cuda:0')
# 0.0023880593944340944 1.5506812632083893
# Test:  tensor([0.7613], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.9280], device='cuda:0')
# 0.002226930228061974 1.526458978652954
# Test:  tensor([0.7637], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.9292], device='cuda:0')
# 0.002638023579493165 1.5435943603515625
# Test:  tensor([0.7697], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.9272], device='cuda:0')
# 0.002210513222962618 1.6016598045825958
# Test:  tensor([0.7579], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.9307], device='cuda:0')
# 0.0020455762278288603 1.5366927087306976
# Test:  tensor([0.7626], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.9324], device='cuda:0')
# 0.0023421536898240447 1.5028607845306396
# Test:  tensor([0.7671], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.9312], device='cuda:0')
# 0.002349582500755787 1.6572261452674866
# Test:  tensor([0.7537], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.9316], device='cuda:0')
# 0.0023721721954643726 1.614646166563034
# Test:  tensor([0.7710], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.9294], device='cuda:0')
# 0.002629991271533072 1.779729276895523
# Test:  tensor([0.7490], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.9294], device='cuda:0')
# 0.002438064315356314 1.8738059103488922
# Test:  tensor([0.7692], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.9336], device='cuda:0')
# 0.0022965336684137583 1.8780793249607086
# Test:  tensor([0.7559], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.9374], device='cuda:0')
# 0.002521866699680686 1.6575444042682648
# Test:  tensor([0.7664], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.9372], device='cuda:0')
# 0.0027193616842851043 1.912272423505783
# Test:  tensor([0.7567], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.9391], device='cuda:0')
# 0.0025940467603504658 1.8404755890369415
# Test:  tensor([0.7647], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.9396], device='cuda:0')
# 0.0022041649790480733 1.9912098944187164
# Test:  tensor([0.7609], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.9410], device='cuda:0')
# 0.0023924869019538164 1.708916336297989
# Test:  tensor([0.7624], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.9413], device='cuda:0')
# 0.0024065066827461123 1.7490760385990143
# Test:  tensor([0.7606], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.9418], device='cuda:0')
# 0.0025348718045279384 1.6126894056797028
# Test:  tensor([0.7650], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.9410], device='cuda:0')
# 0.0024476905819028616 1.7681668996810913
# Test:  tensor([0.7605], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.9424], device='cuda:0')
# 0.0025538362096995115 1.5666882395744324
# Test:  tensor([0.7647], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.9418], device='cuda:0')
# 0.002440508804284036 1.6126063466072083
# Test:  tensor([0.7576], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.9423], device='cuda:0')
# 0.002739142859354615 1.5924009084701538
# Test:  tensor([0.7665], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.9410], device='cuda:0')
# 0.002636381541378796 1.630081832408905
# Test:  tensor([0.7567], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.9426], device='cuda:0')
# 0.002614714438095689 1.5708222687244415
# Test:  tensor([0.7646], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.9421], device='cuda:0')
# 0.0024350304156541824 1.618309885263443
# Test:  tensor([0.7577], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.9436], device='cuda:0')
# 0.002624227781780064 1.5518991947174072
# Test:  tensor([0.7639], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.9429], device='cuda:0')
# 0.0021278351778164506 1.5932014286518097
# Test:  tensor([0.7571], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.9443], device='cuda:0')
# 0.0026987700257450342 1.5607671737670898
# Test:  tensor([0.7625], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.9443], device='cuda:0')
# 0.0026852726005017757 1.6385321915149689
# Test:  tensor([0.7606], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.9453], device='cuda:0')
# 0.002534479135647416 1.5325128138065338
# Test:  tensor([0.7588], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.9456], device='cuda:0')
# 0.0026182555593550205 1.5849273204803467
# Test:  tensor([0.7627], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.9449], device='cuda:0')
# 0.002389900153502822 1.5324160158634186
# Test:  tensor([0.7596], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.9461], device='cuda:0')
# 0.002502135466784239 1.6409383118152618
# Test:  tensor([0.7624], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.9455], device='cuda:0')
# 0.0022978048073127866 1.656024158000946
# Test:  tensor([0.7600], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.9466], device='cuda:0')
# 0.0024497044505551457 1.6375883519649506
# Test:  tensor([0.7619], device='cuda:0') tensor([0.7585], device='cuda:0')
# tensor([0.9464], device='cuda:0')
# 0.00027063069865107536 13.820874214172363
# Test:  tensor([0.5588], device='cuda:0') tensor([0.8517], device='cuda:0')
# tensor([-0.1607], device='cuda:0')
# 0.0002999408170580864 13.128383159637451
# ...
# 0.0016118117928272113 5.485581398010254
# Test:  tensor([0.4438], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.6725], device='cuda:0')
# 0.001558163043227978 5.378052473068237
# Test:  tensor([0.4419], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.6824], device='cuda:0')
# 0.0016345300973625854 5.144028186798096
# Test:  tensor([0.4532], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.6626], device='cuda:0')
# 0.0017138728289864957 4.954266905784607
# Test:  tensor([0.4221], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.7150], device='cuda:0')
# 0.0017134198860730976 4.8374775648117065
# Test:  tensor([0.4429], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.6923], device='cuda:0')
# 0.0017718796443659812 4.602599263191223
# Test:  tensor([0.4174], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.7368], device='cuda:0')
# 0.0017840287764556706 4.519276797771454
# Test:  tensor([0.4237], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.7370], device='cuda:0')
# 0.0018539128504926339 4.344466209411621
# Test:  tensor([0.4287], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.7297], device='cuda:0')
# 0.0018017420370597392 4.148382663726807
# Test:  tensor([0.4023], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.7697], device='cuda:0')
# 0.0019408637599553913 4.13227379322052
# Test:  tensor([0.4259], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.7382], device='cuda:0')
# 0.001943572744494304 3.931038498878479
# Test:  tensor([0.3881], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.7895], device='cuda:0')
# 0.0019269734621047974 4.050311863422394
# Test:  tensor([0.4035], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.7919], device='cuda:0')
# 0.0020289100793888792 3.7873193621635437
# Test:  tensor([0.4094], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.7860], device='cuda:0')
# 0.0020187149348203093 3.517733097076416
# Test:  tensor([0.3840], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.8205], device='cuda:0')
# 0.0020993741927668452 3.5407567620277405
# Test:  tensor([0.3994], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.8122], device='cuda:0')
# 0.001996341336052865 3.25122731924057
# Test:  tensor([0.3771], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.8393], device='cuda:0')
# 0.0021033929951954633 3.3225841522216797
# Test:  tensor([0.3825], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.8458], device='cuda:0')
# 0.0020686333591584116 3.1997973918914795
# Test:  tensor([0.3884], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.8449], device='cuda:0')
# 0.002114420145517215 2.933535575866699
# Test:  tensor([0.3710], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.8684], device='cuda:0')
# 0.002138314419426024 2.9505516290664673
# Test:  tensor([0.3760], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.8729], device='cuda:0')
# 0.0021463674784172326 2.822041392326355
# Test:  tensor([0.3739], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.8810], device='cuda:0')
# 0.002183700737077743 2.6790807843208313
# Test:  tensor([0.3662], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.8930], device='cuda:0')
# 0.002233138569863513 2.608594596385956
# Test:  tensor([0.3664], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.8989], device='cuda:0')
# 0.0023524208809249103 2.504672884941101
# Test:  tensor([0.3678], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.9026], device='cuda:0')
# 0.0022267590975388885 2.4270820319652557
# Test:  tensor([0.3598], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.9136], device='cuda:0')
# 0.0022424148628488183 2.4044450521469116
# Test:  tensor([0.3661], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.9138], device='cuda:0')
# 0.0023151741770561785 2.393898665904999
# Test:  tensor([0.3578], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.9242], device='cuda:0')
# 0.0022463252826128155 2.277414709329605
# Test:  tensor([0.3638], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.9249], device='cuda:0')
# 0.002319012623047456 2.2366263270378113
# Test:  tensor([0.3613], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.9313], device='cuda:0')
# 0.0022194646298885345 2.1871528327465057
# Test:  tensor([0.3609], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.9356], device='cuda:0')
# 0.002212516003055498 2.122573673725128
# Test:  tensor([0.3627], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.9373], device='cuda:0')
# 0.0023170536442194134 2.0953839123249054
# Test:  tensor([0.3564], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.9445], device='cuda:0')
# 0.002303512446815148 2.0822950899600983
# Test:  tensor([0.3649], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.9389], device='cuda:0')
# 0.0023357382451649755 2.0786140263080597
# Test:  tensor([0.3493], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.9507], device='cuda:0')
# 0.0023220042348839343 2.0761949717998505
# Test:  tensor([0.3628], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.9432], device='cuda:0')
# 0.0025083818181883544 1.973052203655243
# Test:  tensor([0.3537], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.9528], device='cuda:0')
# 0.002332992327865213 1.9222024977207184
# Test:  tensor([0.3491], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.9563], device='cuda:0')
# 0.0024297381460200995 1.934270977973938
# Test:  tensor([0.3552], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.9532], device='cuda:0')
# 0.0023945288849063218 1.873157262802124
# Test:  tensor([0.3494], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.9588], device='cuda:0')
# 0.0023283091140910983 1.8365838825702667
# Test:  tensor([0.3487], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.9603], device='cuda:0')
# 0.002369161695241928 1.859032690525055
# Test:  tensor([0.3495], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.9607], device='cuda:0')
# 0.002453704772051424 1.8332335948944092
# Test:  tensor([0.3513], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.9603], device='cuda:0')
# 0.002335172815946862 1.8114441335201263
# Test:  tensor([0.3461], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.9641], device='cuda:0')
# 0.0023976544907782227 1.8094285130500793
# Test:  tensor([0.3483], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.9640], device='cuda:0')
# 0.0024688683915883303 1.7821852266788483
# Test:  tensor([0.3473], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.9648], device='cuda:0')
# 0.002495392080163583 1.7499597072601318
# Test:  tensor([0.3491], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.9636], device='cuda:0')
# 0.0024196099839173257 1.7370427548885345
# Test:  tensor([0.3446], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.9662], device='cuda:0')
# 0.002417971903923899 1.7702951431274414
# Test:  tensor([0.3484], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.9647], device='cuda:0')
# 0.0024681187351234257 1.7169201970100403
# Test:  tensor([0.3468], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.9658], device='cuda:0')
# 0.0024707388365641236 1.708199381828308
# Test:  tensor([0.3391], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.9676], device='cuda:0')
# 0.0024785072600934654 1.8055672347545624
# Test:  tensor([0.3490], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.9649], device='cuda:0')
# 0.002403078688075766 1.6711812913417816
# Test:  tensor([0.3418], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.9683], device='cuda:0')
# 0.0025025896611623466 1.7018388509750366
# Test:  tensor([0.3447], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.9677], device='cuda:0')
# 0.0024834239156916738 1.6695919632911682
# Test:  tensor([0.3442], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.9675], device='cuda:0')
# 0.0023613249068148434 1.6616524755954742
# Test:  tensor([0.3444], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.9668], device='cuda:0')
# 0.002407564257737249 1.6343960762023926
# Test:  tensor([0.3433], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.9664], device='cuda:0')
# 0.0024968385696411133 1.62862029671669
# Test:  tensor([0.3393], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.9673], device='cuda:0')
# 0.0024060348514467478 1.7106971442699432
# Test:  tensor([0.3478], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.9620], device='cuda:0')
# 0.0023803584917914122 1.6538672745227814
# Test:  tensor([0.3379], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.9679], device='cuda:0')
# 0.0025204643316101283 1.689119040966034
# Test:  tensor([0.3444], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.9662], device='cuda:0')
# 0.0024901568540371954 1.5960786938667297
# Test:  tensor([0.3390], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.9688], device='cuda:0')
# 0.002495078690117225 1.6723538041114807
# Test:  tensor([0.3439], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.9676], device='cuda:0')
# 0.0025278928806073964 1.593832552433014
# Test:  tensor([0.3414], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.9689], device='cuda:0')
# 0.0024207378446590155 1.6054950058460236
# Test:  tensor([0.3413], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.9690], device='cuda:0')
# 0.002473319473210722 1.620056003332138
# Test:  tensor([0.3444], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.9676], device='cuda:0')
# 0.002489715669071302 1.5705019533634186
# Test:  tensor([0.3395], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.9689], device='cuda:0')
# 0.0025427638611290604 1.5945614874362946
# Test:  tensor([0.3414], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.9681], device='cuda:0')
# 0.0025350956129841506 1.5862364172935486
# Test:  tensor([0.3426], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.9673], device='cuda:0')
# 0.0025368015631102026 1.554073005914688
# Test:  tensor([0.3421], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.9668], device='cuda:0')
# 0.0025123757077381015 1.5394529402256012
# Test:  tensor([0.3420], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.9663], device='cuda:0')
# 0.002460249641444534 1.5220378637313843
# Test:  tensor([0.3392], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.9665], device='cuda:0')
# 0.002454514382407069 1.5526263117790222
# Test:  tensor([0.3384], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.9661], device='cuda:0')
# 0.002425507496809587 1.587017685174942
# Test:  tensor([0.3414], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.9652], device='cuda:0')
# 0.0024851259076967835 1.5673572719097137
# Test:  tensor([0.3450], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.9631], device='cuda:0')
# 0.0024862483551260084 1.5538071990013123
# Test:  tensor([0.3433], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.9637], device='cuda:0')
# 0.002554538194090128 1.5096395611763
# Test:  tensor([0.3408], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.9644], device='cuda:0')
# 0.0025290949852205813 1.5347921550273895
# Test:  tensor([0.3365], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.9650], device='cuda:0')
# 0.0026014815957751125 1.6398780643939972
# Test:  tensor([0.3476], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.9619], device='cuda:0')
# 0.0025978319463320076 1.6307148933410645
# Test:  tensor([0.3404], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.9663], device='cuda:0')
# 0.0025338172272313386 1.6312966048717499
# Test:  tensor([0.3353], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.9668], device='cuda:0')
# 0.0024586826912127435 1.7233747839927673
# Test:  tensor([0.3524], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.9594], device='cuda:0')
# 0.002602835127618164 1.6187939643859863
# Test:  tensor([0.3335], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.9671], device='cuda:0')
# 0.0024792794429231435 1.7609139680862427
# Test:  tensor([0.3565], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.9551], device='cuda:0')
# 0.0025012236437760293 1.6555117666721344
# Test:  tensor([0.3331], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.9675], device='cuda:0')
# 0.0026079500967171043 1.7414333522319794
# Test:  tensor([0.3543], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.9600], device='cuda:0')
# 0.00252611018368043 1.6059532761573792
# Test:  tensor([0.3350], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.9681], device='cuda:0')
# 0.0024842138518579304 1.6722083687782288
# Test:  tensor([0.3511], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.9644], device='cuda:0')
# 0.0025039208121597767 1.5651161074638367
# Test:  tensor([0.3377], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.9688], device='cuda:0')
# 0.00243526604026556 1.5828150808811188
# Test:  tensor([0.3458], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.9676], device='cuda:0')
# 0.0025207004800904542 1.5179563462734222
# Test:  tensor([0.3377], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.9682], device='cuda:0')
# 0.0025950116687454283 1.5770856440067291
# Test:  tensor([0.3451], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.9666], device='cuda:0')
# 0.0024960987793747336 1.5076202750205994
# Test:  tensor([0.3396], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.9676], device='cuda:0')
# 0.0024674357555340976 1.5169935524463654
# Test:  tensor([0.3396], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.9670], device='cuda:0')
# 0.002527091419324279 1.5241175293922424
# Test:  tensor([0.3408], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.9659], device='cuda:0')
# 0.00255238771205768 1.4745604395866394
# Test:  tensor([0.3360], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.9661], device='cuda:0')
# 0.002424616046482697 1.5330256521701813
# Test:  tensor([0.3375], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.9662], device='cuda:0')
# 0.0025408666988369077 1.4900899231433868
# Test:  tensor([0.3383], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.9661], device='cuda:0')
# 0.002605285058962181 1.4879315495491028
# Test:  tensor([0.3401], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.9650], device='cuda:0')
# 0.0025730428169481456 1.5188333094120026
# Test:  tensor([0.3412], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.9637], device='cuda:0')
# 0.002556343883043155 1.4907013177871704
# Test:  tensor([0.3408], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.9631], device='cuda:0')
# 0.0025606380950193852 1.4605326652526855
# Test:  tensor([0.3385], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.9632], device='cuda:0')
# 0.002602955559268594 1.4837850332260132
# Test:  tensor([0.3333], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.9626], device='cuda:0')
# 0.0026023779064416885 1.672626793384552
# Test:  tensor([0.3495], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.9551], device='cuda:0')
# 0.002567888965131715 1.561735063791275
# Test:  tensor([0.3353], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.9629], device='cuda:0')
# 0.002486667304765433 1.5782595872879028
# Test:  tensor([0.3404], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.9634], device='cuda:0')
# 0.0026655496330931783 1.5410796999931335
# Test:  tensor([0.3446], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.9615], device='cuda:0')
# 0.002537627035053447 1.4892662465572357
# Test:  tensor([0.3376], device='cuda:0') tensor([0.2930], device='cuda:0')
# tensor([0.9644], device='cuda:0')

# %% [markdown]
# ## Model2

# %%
class Model(nn.Module):
    def __init__(
        self
    ):
        super().__init__()

        # self.encoder = nn.Sequential(
        #     nn.Linear(20, 10),
        #     nn.ReLU(),
        #     nn.Linear(10, 5),
        #     nn.Sigmoid()
        # )
        
        # FNN
        self.predictor = nn.Sequential(
            nn.Linear(20, 5),
            # nn.Dropout(0.1),
            nn.ELU(),
            nn.Linear(5, 1),
            nn.Sigmoid()
        )
    
    def forward(
        self,
        x        
    ):
        # z = self.encoder(x)
        labels = self.predictor(x)
        
        # predictor
        # labels = self.predictor(x)
        return labels

def supervised_loss(
    target,
    pred,
    batch_size
):
    
    # yhat_loss = F.mse_loss(pred, target, reduction='sum') / batch_size
    yhat_loss = F.l1_loss(pred, target, reduction='none')

    # sum along rows and norm to batch size
    yhat_loss = yhat_loss.sum(dim=0) / batch_size
    
    # weigths on data
    # yhat_loss = yhat_loss*weights
    # wnorm = yhat_loss / yhat_loss.mean()
    # yhat_loss = yhat_loss*wnorm
    
    return yhat_loss

def get_similarity(a,b):
    sim = (a * b).sum()\
        /(
            torch.sqrt(
                (a**2).sum()
            )
            *
            torch.sqrt(
                (b**2).sum()
            )
        )
    return sim

def unsupervised_loss(
    target_mean,
    pred, 
    batch_size
):
    
    yhat_loss = F.l1_loss(pred, target_mean, reduction='sum') / batch_size
    # yhat_loss = yhat_loss.mean()
    
    # yhat_loss = torch.sqrt(yhat_loss)
    # yhat_loss = -torch.log(yhat_loss)
    yhat_loss = torch.sqrt(yhat_loss)
    return yhat_loss

# %%
# yaug = 0.1

def get_noise(loc, scale, size, coef=0.1):
    
    tril = torch.diag_embed(scale)
    mvn = torch.distributions.MultivariateNormal(
        loc,
        scale_tril=tril
    )
    samples = mvn.sample(torch.Size([size]))
    res = ( samples - samples.mean(dim=0) )*coef

    return res

def get_row_noise(batch, coef):
    # columns_shape = batch.shape[-1]
    columns_mean = batch.mean(dim=1)

    noise1 = torch.rand(*batch.shape)*coef
    noise2 = torch.rand(*batch.shape)*coef

    noise = noise1 - noise2
    # print(batch[0], noise[0] + batch[0])
    # print(batch[0].mean(), (noise[0] + batch[0]).mean())
    return noise
    
    

def train(
    model,
    dataset,
    L,
    u,
    noise_level,
    optimizer,
    epoch_num,
):
        loss_epoch  = 0
        
        yl_epoch_loss = 0
        yu_epoch_loss = 0


        for nbatch, (X,y) in enumerate(dataset):
            # so it is shape of [32, 1]
            y = y[:, 0:1]
            
            y = y.to(device)
            # left only cell 7-6
            
            
            y_deep = torch.clone(y)

            Xl = X[:lbatch]
            Xu = X[lbatch:]
            # print(Xl.shape, Xu.shape)
            yl = y[:lbatch]
            yu = y[lbatch:]


            # aug_u
            Xaug_up = torch.tensor([])
            Xaug_um = torch.tensor([])
            Xaug_l = torch.tensor([])
            Xaug_u_mean = 0
            
            for _ in range(L):
                # aug l part
                # mean_xl = Xl.mean(dim=0)
                # std_xl = Xl.std(dim=0)
                # noise_l = get_noise(
                #     mean_xl,
                #     std_xl,
                #     len(Xl)
                # )
                noise_l = get_row_noise(Xl, noise_level)
                
                Xaug_l = torch.cat(
                    (
                        Xaug_l,
                        Xl + noise_l    
                    ),
                    dim=0
                )
                # print(nbatch, Xl[0])
                
                # aug u part
                # mean_xu = Xu.mean(dim=0)
                # std_xu = Xu.std(dim=0)
            
                # noise_u = get_noise(
                #     mean_xu,
                #     std_xu,
                #     len(Xu)
                # )
                noise_u = get_row_noise(Xu, noise_level)
                # print(mean_xu.shape, noise_u.shape)
                # add
                Xaug_up = torch.cat(
                    (
                        Xaug_up,
                        Xu + noise_u    
                    ),
                    dim=0
                )
                # print(Xu[0], noise_u[0], Xaug_up[0])
                # sub
                Xaug_um = torch.cat(
                    (
                        Xaug_um,
                        Xu - noise_u    
                    ),
                    dim=0
                )
            # simple aug of Xl
            Xaug_l = Xl + noise_l  
            
            # Zero the gradients
            optimizer.zero_grad()

            # Xaug_l = Xaug_l.to(device)
            # NO aug for labeled data
            Xl = Xl.to(device)
            Xu = Xu.to(device)
            Xaug_l = Xaug_l.to(device)
            
            Xaug_up = Xaug_up.to(device)
            Xaug_um = Xaug_um.to(device)
            
            
            labels_l = model(Xaug_l)
            if u == 0:
                labels_l = model(Xl)
            # labels_augl = model(Xaug_l)
            
            labels_up = model(Xaug_up)
            labels_um = model(Xaug_um)

            # lets say it is mean for u data
            labels_u = model(Xu)

            #supervised
            loss_l = supervised_loss(
                yl,
                labels_l,
                Xl.shape[0]
            )
            yl_epoch_loss += loss_l.item()
            
  
            # aug unsupervised
            # chunks to average res
            labels_up_chunks = torch.reshape(
                labels_up, 
                (L, int(labels_up.shape[0]/L), labels_up.shape[-1])
            
            )
            # # chunks to average res
            # labels_um_chunks = torch.reshape(
            #     labels_um, 
            #     (L, int(labels_um.shape[0]/L), labels_um.shape[-1])
            
            # )
            labels_up_mean = labels_up_chunks.mean(dim=0)
            # labels_um_mean = labels_um_chunks.mean(dim=0)

            # labels_upm_mean = (labels_up_mean + labels_um_mean) / 2
            # print(labels_up_chunks.shape, labels_upm_mean.shape, labels_u.shape)
            
            loss_u = unsupervised_loss(
                labels_up_mean,
                labels_u,
                labels_u.shape[0]
            )
            yu_epoch_loss += loss_u.item()
            
            ### Separated plus and minus of u
            # comment out u mean
            # labels_u_mean = labels_u_chunks.mean(dim=0)
            # loss_up = unsupervised_loss(
            #     labels_u_mean,
            #     labels_up_chunks,
            #     labels_u_mean.shape[0]
            # )
            # loss_um = unsupervised_loss(
            #     labels_u_mean,
            #     labels_um_chunks,
            #     labels_u_mean.shape[0]
            # )
            # yu_epoch_loss += (loss_up.item() + loss_um.item())
                
            # loss = loss_l + yaug*loss_yaugl + u*loss_u
            # l + u only
            loss = loss_l + u*loss_u
            loss.backward()
            optimizer.step()
            
            loss_epoch += loss.item()
            
            
        loss_epoch = loss_epoch / len(dataset)
        yl_epoch_loss = yl_epoch_loss / len(dataset)
        yu_epoch_loss = yu_epoch_loss / len(dataset)
    
        print(
            yu_epoch_loss,
            yl_epoch_loss,
            
        )

        return loss_epoch, yl_epoch_loss, yu_epoch_loss

# %%
def test(
    model,
    dataset,
    L,
    epoch_num
):

        loss_epoch = 0
        r2_epoch = 0
        with torch.no_grad():
            for nbatch, (X,y) in enumerate(dataset):
                # so it is shape of [32, 1]
                y = y[:, 0:1]
                
                
                y = y.to(device)
                y_deep = torch.clone(y)

                X = X.to(device)
                
                labels = model(X)

                # print(
                #     "Test: ",
                #     labels[0],
                #     y[0]
                # )

                loss = F.l1_loss(labels, y)
                loss_epoch += loss.item()
                
                r2 = r2_score(labels, y, multioutput="raw_values")
                r2_mean = r2.mean()
                r2_epoch += r2_mean.item()
                
            
            loss_epoch = loss_epoch / len(dataset)
            r2_epoch = r2_epoch / len(dataset)

            return loss_epoch, r2_epoch

# %%
U = [0, 0.001, 0.01, 0.1, 0.2, 0.4, 0.5]
# U = [0.05]
Ls = [1,4]
# Ls = [1]

noise=0.005
for u in U:
    for L in Ls:
        writer = SummaryWriter(f'ssl/akaMixMatch_negUloss_noise{noise}_yl_yu_losses_1label_Xaug_l/RUL_{RUL}/L{L}/{u}_ucoef_te')
        
        train_loss_cv, train_yl_loss_cv, train_yu_loss_cv = [], [], []
        test_loss_cv, test_r2_cv = [], []
        
        for (xy_train, xy_test) in cv_datasets:
            model = Model().to(device)
            adam = torch.optim.Adam(model.parameters())
            epoch = 450

            train_loss_epoches, train_yl_loss_epoches, train_yu_loss_epoches = [], [], []
            test_loss_epoches, test_r2_epoches = [], []
            for e in range(epoch):
                train_loss_epoch, train_yl_epoch_loss, train_yu_epoch_loss = train(
                    model,
                    xy_train,
                    L,
                    u,
                    noise,
                    adam,
                    e
                )
                train_loss_epoches.append(train_loss_epoch)
                train_yl_loss_epoches.append(train_yl_epoch_loss)
                train_yu_loss_epoches.append(train_yu_epoch_loss)
                 
                test_loss_epoch, test_r2_epoch = test(
                    model,
                    xy_test,
                    L,
                    e
                )
                test_loss_epoches.append(test_loss_epoch)
                test_r2_epoches.append(test_r2_epoch)
            
            train_loss_cv.append(train_loss_epoches)
            train_yl_loss_cv.append(train_yl_loss_epoches)
            train_yu_loss_cv.append(train_yu_loss_epoches)
            
            test_loss_cv.append(test_loss_epoches)
            test_r2_cv.append(test_r2_epoches)
        
        # averaging results over cv
        train_loss_cv = np.asarray(train_loss_cv).mean(axis=0)
        train_yl_loss_cv = np.asarray(train_yl_loss_cv).mean(axis=0)
        train_yu_loss_cv = np.asarray(train_yu_loss_cv).mean(axis=0)
        
        test_loss_cv = np.asarray(test_loss_cv).mean(axis=0)
        test_r2_cv = np.asarray(test_r2_cv).mean(axis=0)
        
        # adding to writer
        for e in range(len(test_loss_cv)):
            # print(e)
            writer.add_scalar('Train/epoch_loss', train_loss_cv[e], global_step=e)
            writer.add_scalar('Train/yl_Loss', train_yl_loss_cv[e], global_step=e)
            writer.add_scalar('Train/yu_Loss', train_yu_loss_cv[e], global_step=e)
            
            
            writer.add_scalar('Test/y_loss', test_loss_cv[e], global_step=e)
            writer.add_scalar('Test/r2_mean', test_r2_cv[e], global_step=e)
        if u == 0:
            break
# Out:
# 0.009978823945857584 0.1498442441225052
# 0.00990688952151686 0.14747645985335112
# 0.009940889431163669 0.14593340177088976
# 0.009994496474973857 0.14503079280257225
# 0.009892572299577296 0.14445467293262482
# 0.009906658437103033 0.1439882181584835
# 0.009750172612257302 0.14354005083441734
# 0.00984264223370701 0.143194985575974
# 0.009849493973888457 0.14287942368537188
# 0.00970944738946855 0.1425630133599043
# 0.009894297108985484 0.1422463320195675
# 0.009935144684277475 0.14192915055900812
# 0.009672050015069544 0.1416613319888711
# 0.009881759877316654 0.1413931678980589
# 0.009836107608862221 0.1411018678918481
# 0.010005123098380864 0.14079414121806622
# 0.010005485615693033 0.14047195948660374
# 0.009988746140152216 0.14012767281383276
# 0.009970723069272935 0.13975699990987778
# 0.010038100532256067 0.13942154869437218
# 0.010187029838562012 0.1390730533748865
# 0.010354785365052521 0.1386776864528656
# 0.010443569393828511 0.1382545130327344
# 0.01055587362498045 0.13786092959344387
# 0.01037347165402025 0.13741768430918455
# 0.010738788056187332 0.13697645533829927
# 0.010758903808891773 0.13649657927453518
# 0.011013133218511939 0.13597690407186747
# 0.011164105031639338 0.13545486889779568
# 0.011252407566644251 0.1349560236558318
# 0.01151095877867192 0.1344424383714795
# 0.01155995239969343 0.13390968833118677
# 0.011723214411176741 0.1333552161231637
# 0.012033837498165667 0.1327772717922926
# 0.012254738481715322 0.13217442389577627
# 0.012190140667371452 0.1315458146855235
# 0.012544694938696921 0.13089037965983152
# 0.01260497304610908 0.13020692113786936
# 0.012983749969862401 0.12949426751583815
# 0.013377583352848887 0.12875164486467838
# 0.013612673501484096 0.12797845341265202
# 0.013483255635946989 0.1271738139912486
# 0.01404182962141931 0.12633652985095978
# 0.014280029339715838 0.1255589360371232
# 0.014605971402488649 0.12461649067699909
# 0.014929782832041383 0.12365844752639532
# 0.01510665810201317 0.12267310544848442
# 0.015479227062314749 0.12176157254725695
# 0.015781267662532628 0.12066040467470884
# 0.01626314385794103 0.11949092708528042
# 0.016359658678993583 0.11861533019691706
# 0.016800687182694674 0.11746494378894567
# 0.01716908230446279 0.11627598758786917
# 0.017602154053747654 0.11507966462522745
# 0.017629084875807166 0.11385992541909218
# 0.01811785134486854 0.1126090232282877
# 0.018426965456455946 0.11132286954671144
# 0.018514664145186543 0.10997918993234634
# 0.01910069747827947 0.10870288591831923
# 0.019367140717804432 0.10729993227869272
# 0.020117316860705614 0.10607985127717257
# 0.019994759699329734 0.10456570610404015
# 0.02042024675756693 0.10309794917702675
# 0.021187229547649622 0.10164453461766243
# 0.02119326964020729 0.10006941854953766
# 0.021521113347262144 0.09855140373110771
# 0.02206849097274244 0.09683174267411232
# 0.02260313741862774 0.09541989583522081
# 0.02268366701900959 0.09350419929251075
# 0.02281672856770456 0.09208884928375483
# 0.023806823883205652 0.09028885932639241
# 0.023976406082510948 0.08856914844363928
# 0.02427952433936298 0.08699097065255046
# 0.024462218629196286 0.08530116127803922
# 0.02501337928697467 0.08362126210704446
# 0.02492708689533174 0.08193221827968955
# 0.025130833499133587 0.08023070683702826
# 0.026020935969427228 0.07875666627660394
# 0.026151274098083377 0.07716487254947424
# 0.02641494758427143 0.07560092490166426
# 0.02695671282708645 0.07429529214277864
# 0.02718236786313355 0.07258415035903454
# 0.02738342876546085 0.07082496676594019
# 0.027586094569414854 0.0697429277934134
# 0.027903483482077718 0.06793435337021947
# 0.027855645399540663 0.06695996783673763
# 0.028507757000625134 0.06593794701620936
# 0.029044916154816747 0.06470695184543729
# 0.028722514864057302 0.06369931856170297
# 0.029411665862426162 0.06268223468214273
# 0.02926501608453691 0.061422720551490784
# 0.029987488640472293 0.06099024321883917
# 0.02955253329128027 0.05949419271200895
# 0.029946286231279373 0.05891577247530222
# 0.030568795977160335 0.05746691254898906
# 0.03055197815410793 0.056572013068944216
# 0.030568035785108805 0.05553374858573079
# 0.0314673890825361 0.05437286105006933
# 0.03097068495117128 0.05422971723601222
# 0.03148359805345535 0.05253650667145848
# 0.0317358688917011 0.05248602060601115
# 0.03133827541023493 0.05079195322468877
# 0.031969306990504265 0.04942777752876282
# 0.03179131727665663 0.04874880751594901
# 0.03211496095173061 0.04736343724653125
# 0.032648681197315454 0.04672997957095504
# 0.03271189937368035 0.04540743259713054
# 0.03311752760782838 0.04491600068286061
# 0.032647496555000544 0.043742377776652575
# 0.03343495586887002 0.0436473791487515
# 0.03328115213662386 0.0421853675507009
# 0.033915900625288486 0.04227773239836097
# 0.03380029136314988 0.04070269502699375
# 0.03341130632907152 0.04114272864535451
# 0.03387416899204254 0.03962892945855856
# 0.03445223160088062 0.0409033284522593
# 0.03398082545027137 0.038946764543652534
# 0.03440287662670016 0.038392165675759315
# 0.03450913541018963 0.0376175488345325
# 0.034298538230359554 0.03744607139378786
# 0.03479206329211593 0.03657187381759286
# 0.034971282351762056 0.03636881057173014
# 0.0348738981410861 0.03560311393812299
# 0.034690653439611197 0.035234959330409765
# 0.03528096852824092 0.03482430661097169
# 0.03521951520815492 0.03454583045095205
# 0.0352088394574821 0.03417924419045448
# 0.035093515645712614 0.03338643489405513
# 0.03510070452466607 0.03294345922768116
# 0.035680408123880625 0.032538377214223146
# 0.035513284150511026 0.03205973096191883
# 0.03515848936513066 0.031772490590810776
# 0.03576830914244056 0.0315984976477921
# 0.03540548635646701 0.0312314429320395
# 0.03575678449124098 0.030730257276445627
# 0.03647084441035986 0.030267965979874134
# 0.035835253074765205 0.029891458339989185
# 0.0360923083499074 0.029770532622933388
# 0.03634717641398311 0.029124503955245018
# 0.03663868550211191 0.028841088991612196
# 0.036359797697514296 0.028271077433601022
# 0.03652060171589255 0.02795561053790152
# 0.036255162209272385 0.027441242011263967
# 0.03755113389343023 0.027174170361831784
# 0.0364938136190176 0.02688701869919896
# 0.036572807002812624 0.026826640591025352
# 0.03638641396537423 0.0263820243999362
# 0.03670261148363352 0.025951892836019397
# 0.036781988106667995 0.025575576350092888
# 0.036913327407091856 0.02546580135822296
# 0.03643627883866429 0.025064743123948574
# 0.03698231326416135 0.024818046018481255
# 0.03710892843082547 0.02482387493364513
# 0.03692154912278056 0.02418568031862378
# 0.037631351966410875 0.02404162986204028
# 0.03666004305705428 0.02371408767066896
# 0.03746078768745065 0.023409336572512984
# 0.03749253507703543 0.023134073242545128
# 0.03723911847919226 0.023357870522886515
# 0.037696192506700754 0.022746086353436112
# 0.03725998243317008 0.02237832685932517
# 0.037471603602170944 0.022194921039044857
# 0.036863263230770826 0.02195925754494965
# 0.03724663518369198 0.021620370913296938
# 0.03697037184610963 0.02146050240844488
# 0.038101805839687586 0.021420662524178624
# 0.03723279433324933 0.02155529474839568
# 0.03735303087159991 0.02118784189224243
# 0.03786766901612282 0.020994697464630008
# 0.03810958471149206 0.0212004529312253
# 0.03821995574980974 0.020360731286928058
# 0.037616734858602285 0.021001225570216775
# 0.037395613733679056 0.020945938304066658
# 0.038327041547745466 0.021596091799438
# 0.03851736942306161 0.02139443694613874
# 0.03800631780177355 0.021283978829160333
# 0.03692786442115903 0.020763975800946355
# 0.03765179682523012 0.02079985965974629
# 0.03861813759431243 0.02001380082219839
# 0.03835797356441617 0.02099377056583762
# 0.03804142028093338 0.020417371531948447
# 0.03831001138314605 0.02167514734901488
# 0.038214681670069695 0.020366308046504855
# 0.03799729933962226 0.022193501004949212
# 0.03868149733170867 0.020329482853412628
# 0.038462250493466854 0.020170326344668865
# 0.03836345253512263 0.018920063273981214
# 0.038721862249076366 0.01957626431249082
# 0.03825105773285031 0.01828544889576733
# 0.03845921065658331 0.018260055454447865
# 0.038802328053861856 0.018014702945947647
# 0.03824419109150767 0.01775308814831078
# 0.038052869495004416 0.017741925083100796
# 0.03825609292834997 0.017611378338187933
# 0.0387379233725369 0.0172624287661165
# 0.03871876606717706 0.017211085185408592
# 0.03908604336902499 0.017305995570495725
# 0.03856381727382541 0.016941607696935534
# 0.03826316585764289 0.016992134042084217
# 0.03928658785298467 0.016971316887065768
# 0.03883765172213316 0.0169541472569108
# 0.03846709430217743 0.016756908036768436
# 0.039207004476338625 0.016525002662092447
# 0.03898338973522186 0.016618181252852082
# 0.038798286113888025 0.01664205826818943
# 0.03947559045627713 0.016464336309581995
# 0.03905291063711047 0.01649991818703711
# 0.03888455452397466 0.016775431344285607
# 0.03859372762963176 0.016252152621746063
# 0.038726283237338066 0.01665195496752858
# 0.038799907080829144 0.016165272565558553
# 0.03878401778638363 0.016318632755428553
# 0.03914835676550865 0.01626821793615818
# 0.039426601491868496 0.016023304546251893
# 0.039341692347079515 0.01639378909021616
# 0.038874171674251556 0.015937110176309943
# 0.03875072859227657 0.016396048478782177
# 0.03901235992088914 0.01658448181115091
# 0.038703178986907005 0.015805408591404557
# 0.039318816270679235 0.016044060001149774
# 0.039593013003468513 0.016073450446128845
# 0.03899372788146138 0.01581164076924324
# 0.03929222049191594 0.015810901997610927
# 0.03927429532632232 0.01575673627667129
# 0.03970816591754556 0.015931813279166818
# 0.03876298852264881 0.01577534177340567
# 0.03935439186170697 0.015606902306899428
# 0.03890889137983322 0.01569869974628091
# 0.039237347431480885 0.015752760227769613
# 0.03877538675442338 0.015605638502165675
# 0.038857247680425644 0.015744769712910056
# 0.039867852348834276 0.015482912538573146
# 0.03902734303846955 0.01538002910092473
# 0.03924800595268607 0.015413082437589765
# 0.03887113928794861 0.016097732121124864
# 0.03854939807206392 0.015697633614763618
# 0.03899314533919096 0.015676076291128993
# 0.039000390097498894 0.01549501996487379
# 0.039597684517502785 0.015441359020769596
# 0.039316951762884855 0.0155199458822608
# 0.03940605418756604 0.015358213568106294
# 0.039575725328177214 0.015321213053539395
# 0.03984891017898917 0.015328363049775362
# 0.038931616581976414 0.01565489126369357
# 0.03954953094944358 0.016012588515877724
# 0.039346626959741116 0.015604972606524825
# 0.03907302487641573 0.015313526149839163
# 0.03945975657552481 0.015158899361267686
# 0.03915051091462374 0.015147130936384201
# 0.039591771084815264 0.015154117718338966
# 0.03933533979579806 0.01576880714856088
# 0.03934260131791234 0.015508339507505298
# 0.04001843463629484 0.01543690636754036
# 0.04046665085479617 0.015258268220350146
# 0.04003799660131335 0.015112488996237516
# 0.03930472116917372 0.015079326462000608
# 0.03990511829033494 0.01518918969668448
# 0.03961647069081664 0.015305645763874054
# 0.040025738067924976 0.016221129335463047
# 0.039081535302102566 0.016358897788450122
# 0.038757394067943096 0.015252513578161597
# 0.03927291464060545 0.016143720597028732
# 0.0397151792421937 0.0175511185079813
# 0.0390462726354599 0.01662776223383844
# 0.03895336342975497 0.01719709695316851
# 0.03997064009308815 0.01555527257733047
# 0.039363508112728596 0.01536056469194591
# 0.03966340981423855 0.015476704342290759
# 0.03951544826850295 0.015258645173162222
# 0.039483904372900724 0.015131991589441895
# 0.03948920872062445 0.015091231325641274
# 0.03967124503105879 0.015081332763656974
# 0.03947102790698409 0.01519252103753388
# 0.0392822353169322 0.015048050321638584
# 0.03978319792076945 0.015086717437952757
# 0.03985621500760317 0.015205938601866364
# 0.03928005648776889 0.015390592627227306
# 0.039497291669249535 0.014934801263734698
# 0.03929739631712437 0.015357002150267363
# 0.03968930384144187 0.015442752046510577
# 0.03913709847256541 0.015331892063841224
# 0.03970234747976065 0.01530283153988421
# 0.03909891005605459 0.014919907785952091
# 0.040251719765365124 0.015134647954255342
# 0.03968265559524298 0.015143212163820863
# 0.03929315973073244 0.015101059572771192
# 0.039809076115489006 0.015110323205590248
# 0.03905920358374715 0.014973335899412632
# 0.03968144208192825 0.014884754084050655
# 0.039443510584533215 0.014791153836995363
# 0.039013238158077 0.015024405904114246
# 0.0398038849234581 0.015035456046462059
# 0.03955788258463144 0.015115826856344938
# 0.039649311918765306 0.014871278312057257
# 0.03962781745940447 0.01508281915448606
# 0.03945897379890084 0.016398928128182888
# 0.03992889542132616 0.015790268313139677
# 0.03966772696003318 0.015623090090230107
# 0.03960567992180586 0.014982879627496004
# 0.03989852452650666 0.015252937097102404
# 0.039783159736543894 0.014934812672436237
# 0.039734180085361004 0.015027175890281796
# 0.040145162492990494 0.014979088911786675
# 0.039691501297056675 0.014935769373551011
# 0.03959151217713952 0.01490846136584878
# 0.04022876778617501 0.014857464469969273
# 0.0400206483900547 0.015079347183927894
# 0.039610715582966805 0.01616963022388518
# 0.03977999510243535 0.01505458285100758
# 0.03958899946883321 0.014901747927069664
# 0.03947361186146736 0.014963123481720686
# 0.039299885742366314 0.015038951532915235
# 0.03936454886570573 0.01483899261802435
# 0.0398041014559567 0.015017306432127953
# 0.03943757014349103 0.01611984707415104
# 0.040108144748955965 0.015468793455511332
# 0.03924615401774645 0.015185864409431815
# 0.03953984100371599 0.01617981307208538
# 0.03944212989881635 0.015353994211181998
# 0.039778837002813816 0.015301153063774109
# 0.03985286271199584 0.014761338708922267
# 0.03944318275898695 0.014809659216552973
# 0.03905426897108555 0.014844379387795925
# 0.039819156751036644 0.014740960206836462
# 0.039380439557135105 0.014705776702612638
# 0.03916992526501417 0.01491752383299172
# 0.03942045196890831 0.014881564304232597
# 0.03972766501829028 0.014990255702286959
# 0.039369664154946804 0.014959272695705295
# 0.039941072929650545 0.014785093488171697
# 0.039670996367931366 0.014990823110565543
# 0.03981244517490268 0.014901218935847282
# 0.03935420326888561 0.01471704593859613
# 0.039538499899208546 0.014865947654470801
# 0.03970615612342954 0.015416293870657682
# 0.03968220204114914 0.014746983768418431
# 0.03967458289116621 0.014775897609069943
# 0.039193297270685434 0.014894965337589383
# 0.040323796682059765 0.014842362143099308
# 0.03900767583400011 0.014725597808137536
# 0.03966842545196414 0.01487313350662589
# 0.039589094929397106 0.014817388029769063
# 0.03982360241934657 0.014856889378279448
# 0.04010206647217274 0.014909335179254413
# 0.039949302561581135 0.015330155612900853
# 0.039854143280535936 0.014614467974752188
# 0.03925222111865878 0.014820907032117248
# 0.03997459029778838 0.014842898119241
# 0.038962483406066895 0.014784123050048947
# 0.039798200596123934 0.014704450964927673
# 0.03901203302666545 0.014779602643102407
# 0.03951815376058221 0.014877733308821917
# 0.03990035504102707 0.01571531710214913
# 0.039709709119051695 0.014874489977955818
# 0.03953569009900093 0.014712819829583168
# 0.03957289271056652 0.01494244346395135
# 0.03957800706848502 0.01466112257912755
# 0.04043488437309861 0.014904457842931151
# 0.03969692997634411 0.014976145699620247
# 0.03949787747114897 0.015100691933184862
# 0.039653546176850796 0.014803684782236814
# 0.040091500617563725 0.014799631899222732
# 0.03959759417921305 0.01479962863959372
# 0.04011549474671483 0.014768591849133372
# 0.03981777234002948 0.014761014375835657
# 0.03895507659763098 0.014636971289291978
# 0.03923407196998596 0.014624126255512238
# 0.04020335804671049 0.015196150401607156
# 0.03976878151297569 0.014780601253733039
# 0.039726749528199434 0.014901636401191354
# 0.03988532302901149 0.014576253481209278
# 0.039876754861325026 0.014732646755874157
# 0.04003828577697277 0.014751097187399864
# 0.03987880004569888 0.015088274842128158
# 0.03926610201597214 0.01487530255690217
# 0.03955289348959923 0.015164633514359593
# 0.04011354874819517 0.014651130884885788
# 0.039706259965896606 0.014674433507025242
# 0.03955884324386716 0.014613732229918242
# 0.039958156645298004 0.01621080795302987
# 0.03942028898745775 0.01546026230789721
# 0.039660362526774406 0.01644276431761682
# 0.039990561082959175 0.016097439918667078
# 0.03990209847688675 0.017687123734503984
# 0.03964726533740759 0.016870069783180952
# 0.03990286448970437 0.019156526075676084
# 0.039981720969080925 0.018771732924506068
# 0.039428552612662315 0.018279365496709943
# 0.040035545360296965 0.01612964295782149
# 0.039658410008996725 0.017917157150804996
# 0.03989395685493946 0.01700702798552811
# 0.03921532304957509 0.018407627940177917
# 0.0399688770994544 0.017817380605265498
# 0.0399911398999393 0.0186072182841599
# 0.039674365893006325 0.01602582400664687
# 0.039576733484864235 0.017949280561879277
# 0.039813792798668146 0.01688852277584374
# 0.03972483891993761 0.01757947471924126
# 0.03994641685858369 0.01632867963053286
# 0.04016058426350355 0.017534089973196387
# 0.040162752848118544 0.016953626880422235
# 0.04043333372101188 0.017896500416100025
# 0.039594555739313364 0.016699435422196984
# 0.040296309161931276 0.017415148904547095
# 0.039779762737452984 0.01645750063471496
# 0.040269114542752504 0.016263911267742515
# 0.03955918038263917 0.015337181743234396
# 0.04016083478927612 0.016488455003127456
# 0.03959160577505827 0.01577786263078451
# 0.03966911556199193 0.017286823596805334
# 0.03980653407052159 0.015774534782394767
# 0.03990009054541588 0.017882817424833775
# 0.03948447108268738 0.017059657955542207
# 0.03921749582514167 0.017915167612954974
# 0.03980414057150483 0.01620808313600719
# 0.03951658168807626 0.01721679512411356
# 0.0395640661008656 0.01589219504967332
# 0.040020162239670753 0.016734209842979908
# 0.040026962757110596 0.01602249057032168
# 0.0401887777261436 0.016587325371801853
# 0.04004888562485576 0.015729000326246023
# 0.03982827300205827 0.016258254181593657
# 0.03997293720021844 0.015553154982626438
# 0.040000530425459146 0.015893914736807346
# 0.039607417304068804 0.015341121004894376
# 0.03999450337141752 0.01584070036187768
# 0.04020944610238075 0.015176166780292988
# 0.039757121820002794 0.015579316532239318
# 0.03912826208397746 0.01503275940194726
# 0.03986449493095279 0.014935830608010292
# 0.03968160133808851 0.015084822196513414
# 0.03942871326580644 0.014768216526135802
# 0.03977923700585961 0.0151258809491992
# 0.039514042902737856 0.014752156101167202
# 0.040035718120634556 0.015021955594420433
# 0.039142369758337736 0.014731868635863066
# 0.03997174883261323 0.014967270661145449
# 0.0394361331127584 0.01480086357332766
# 0.03978123050183058 0.014608855126425624
# 0.04003586433827877 0.01562375365756452
# 0.04016817361116409 0.015040270984172821
# 0.04033483564853668 0.01544573507271707
# 0.039981197100132704 0.014877313980832696
# 0.039126873947679996 0.01491774246096611
# 0.04073375929147005 0.015244877198711038
# 0.03942539496347308 0.014698714017868042
# 0.03927375329658389 0.01608062954619527
# 0.03990732645615935 0.01539122499525547
# 0.0396002153865993 0.016621696762740612
# 0.039538397919386625 0.01494902977719903
# 0.009814407909289002 0.13853644393384457
# 0.00967782863881439 0.13801148161292076
# 0.009842498693615198 0.13766798190772533
# 0.00945197232067585 0.13734563067555428
# 0.00955490826163441 0.13703585136681795
# 0.009518593433313072 0.13676573801785707
# 0.009426263510249555 0.13655027467757463
# 0.009536154102534056 0.1363407066091895
# 0.009483731351792812 0.13613441586494446
# 0.009440584108233452 0.13592973444610834
# 0.0094105004100129 0.1357254944741726
# 0.009489200194366276 0.13552080653607845
# 0.00940297928173095 0.13531484454870224
# 0.009370995569042861 0.13510689791291952
# 0.00938197725918144 0.1349030937999487
# 0.009528014459647238 0.13473378587514162
# 0.00950791744980961 0.13455633260309696
# 0.009476990206167102 0.1343723675236106
# 0.00949616206344217 0.1341823535040021
# 0.009679201524704695 0.13398620672523975
# 0.009606548817828298 0.13378363754600286
# 0.00960619654506445 0.1335742324590683
# 0.009973748703487217 0.13335753977298737
# 0.00990386598277837 0.1331331068649888
# 0.009768422809429467 0.13290043082088232
# 0.009940493968315423 0.1326590385288
# 0.010054832324385643 0.13240840006619692
# 0.010125832166522741 0.13214800879359245
# 0.010244895005598664 0.13187736179679632
# 0.01031730161048472 0.13159599713981152
# 0.010387948132120073 0.13130339328199625
# 0.010494741261936724 0.1310112765058875
# 0.010551128652878106 0.13068878557533026
# 0.01079150557052344 0.1303657814860344
# 0.010904795140959322 0.1300477422773838
# 0.01091370196081698 0.1297026788815856
# 0.01123843458481133 0.12936022318899632
# 0.011171345948241651 0.12898615654557943
# 0.011401406838558614 0.12862500548362732
# 0.011518414015881717 0.12825563177466393
# 0.011795356404036283 0.12789408583194017
# 0.011738665984012187 0.12751621939241886
# 0.011884828680194914 0.1271226704120636
# 0.012037573964335024 0.12671334203332663
# 0.012395875179208815 0.12628782913088799
# 0.012460933299735188 0.12581354193389416
# 0.012738030985929072 0.1253728112205863
# 0.0127472176682204 0.12490960862487555
# 0.013194730738177896 0.12442106194794178
# 0.01312336465343833 0.12391040753573179
# 0.013268821290694177 0.12337239645421505
# 0.01362183375749737 0.12285510636866093
# 0.013865798246115446 0.12231399212032557
# 0.014253824134357274 0.12174911797046661
# 0.014195993426255882 0.12115705851465464
# 0.014490975183434784 0.12057637516409159
# 0.014773160219192505 0.12002488877624273
# 0.015161078656092286 0.11937925219535828
# 0.015230553108267486 0.11871375050395727
# 0.015400081407278776 0.11809204053133726
# 0.01570149918552488 0.11742853838950396
# 0.015744742238894105 0.11669865064322948
# 0.01603089109994471 0.11594844702631235
# 0.01640957221388817 0.11523723136633635
# 0.016475945711135864 0.11443769559264183
# 0.016878547379747033 0.11367296054959297
# 0.016964462818577886 0.11282867006957531
# 0.017285597743466496 0.1119613815099001
# 0.017670967848971486 0.11113223247230053
# 0.017963055055588484 0.11019791755825281
# 0.018275849288329482 0.10946150869131088
# 0.018494494259357452 0.10864001978188753
# 0.01875688973814249 0.10772398300468922
# 0.019096423871815205 0.10682678688317537
# 0.019289246760308743 0.1059666434302926
# 0.019651211565360427 0.10508027486503124
# 0.01992436032742262 0.10418510530143976
# 0.019896148005500436 0.1032820362597704
# 0.020520954625681043 0.10259899776428938
# 0.020694721955806017 0.10180235002189875
# 0.020981822395697236 0.10075801983475685
# 0.021017235703766346 0.1000340674072504
# 0.02140894648618996 0.09918868448585272
# 0.021524871233850718 0.09812890831381083
# 0.02190142567269504 0.09729839209467173
# 0.02212610561400652 0.09613708313554525
# 0.022038244642317295 0.09542111586779356
# 0.022638637106865644 0.09455551765859127
# 0.02319263480603695 0.09355114819481969
# 0.023132168455049396 0.09237319277599454
# 0.02332187141291797 0.09142960701137781
# 0.02339519001543522 0.09050322975963354
# 0.024023660691455007 0.0895066293887794
# 0.023702554870396852 0.08817075844854116
# 0.02441303408704698 0.08733721543103456
# 0.024870399618521333 0.08628025138750672
# 0.024814088828861713 0.08501421520486474
# 0.025072867050766945 0.08401677338406444
# 0.02535648294724524 0.08315803110599518
# 0.025695670628920197 0.0820613051764667
# 0.025608703959733248 0.08097817050293088
# 0.026325901970267296 0.07989393593743443
# 0.02631369954906404 0.07871769741177559
# 0.02682084427215159 0.0778403296135366
# 0.02717937179841101 0.07676773564890027
# 0.02652402874082327 0.07554668141528964
# 0.027384091168642044 0.07466586865484715
# 0.027571275364607573 0.07365362858399749
# 0.02790910704061389 0.07268349174410105
# 0.02797565539367497 0.07172359619289637
# 0.02815933059900999 0.07081057783216238
# 0.02832643734291196 0.06988364830613136
# 0.028534343000501394 0.06894195778295398
# 0.02902711625210941 0.06787951989099383
# 0.028821942629292607 0.06710918946191669
# 0.02922571008093655 0.06587000330910087
# 0.029512361157685518 0.06533745769411325
# 0.02956718229688704 0.06403007917106152
# 0.029446728993207216 0.06304282741621137
# 0.02949959388934076 0.06203968217596412
# 0.029778083553537726 0.06108793010935187
# 0.02982207969762385 0.060209089424461126
# 0.030498351901769638 0.059152517933398485
# 0.030139811104163527 0.05869557661935687
# 0.030710247810930014 0.057244866620749235
# 0.030391754815354943 0.057606423273682594
# 0.030993533320724964 0.05587366595864296
# 0.03115331823937595 0.055712159257382154
# 0.0314836495090276 0.054144308902323246
# 0.03163956804201007 0.05382285779342055
# 0.03210180997848511 0.05238613625988364
# 0.03186511155217886 0.05335126118734479
# 0.032320900820195675 0.0512564885430038
# 0.03213993809185922 0.05082657700404525
# 0.03254190133884549 0.05010754941031337
# 0.03275753604248166 0.049283336382359266
# 0.03252812707796693 0.0492290947586298
# 0.03309042006731033 0.0478401412256062
# 0.03325536847114563 0.04696742258965969
# 0.033036548644304276 0.046378386206924915
# 0.033136476296931505 0.04555280413478613
# 0.03323909221217036 0.04476477252319455
# 0.03377304971218109 0.04407632723450661
# 0.033968265634030104 0.043473003432154655
# 0.03389085968956351 0.04271217714995146
# 0.03434129757806659 0.042534243781119585
# 0.03405627142637968 0.04130051890388131
# 0.034986983984708786 0.04125157743692398
# 0.034128882456570864 0.03993014292791486
# 0.03427751874551177 0.03973172698169947
# 0.034658240620046854 0.038912381045520306
# 0.03461145516484976 0.03928649052977562
# 0.035549013409763575 0.037686839466914535
# 0.03525946754962206 0.03709793882444501
# 0.0355230001732707 0.03619286115281284
# 0.035808864049613476 0.03574230172671378
# 0.03569429134950042 0.03493275842629373
# 0.035998869221657515 0.0343561542686075
# 0.03565904824063182 0.03364557051099837
# 0.03602967318147421 0.033072987804189324
# 0.03599382238462567 0.03273272910155356
# 0.035903435200452805 0.03191108745522797
# 0.03596845734864473 0.031629147473722696
# 0.03659090679138899 0.03104224242269993
# 0.036579358857125044 0.031485775485634804
# 0.03730403585359454 0.03062762855552137
# 0.036821513902395964 0.031637264881283045
# 0.03652252955362201 0.029437669785693288
# 0.03659104462713003 0.02887252368964255
# 0.03739957790821791 0.027868294157087803
# 0.037352763582021 0.02720116451382637
# 0.0372595083899796 0.026573288487270474
# 0.03714982932433486 0.026187244337052107
# 0.037167918868362904 0.025424934457987547
# 0.03746877983212471 0.024851654889062047
# 0.037766220048069954 0.02427837159484625
# 0.03802256332710385 0.023848133627325296
# 0.03798789298161864 0.02329020923934877
# 0.03757897671312094 0.022849583765491843
# 0.0384578974917531 0.022380351554602385
# 0.03855094267055392 0.02241262304596603
# 0.03792039444670081 0.021969340974465013
# 0.03851497219875455 0.0214625122025609
# 0.03837755182757974 0.021556529914960265
# 0.03866287600249052 0.020988212432712317
# 0.0387941631488502 0.020517946453765035
# 0.03888261551037431 0.02024353202432394
# 0.03870772337540984 0.02020969078876078
# 0.03865825803950429 0.019815360894426703
# 0.0393396676518023 0.01962479716166854
# 0.03942765202373266 0.019771910971030593
# 0.038673663046211004 0.019083017949014902
# 0.03870914550498128 0.018892402295023203
# 0.038880125153809786 0.018716728780418634
# 0.03942326037213206 0.018314097309485078
# 0.038922582753002644 0.018247693311423063
# 0.0393467890098691 0.018085045972838998
# 0.03943901788443327 0.01778350444510579
# 0.03952925140038133 0.01775298034772277
# 0.039439912885427475 0.0179015239700675
# 0.039299922063946724 0.0174409756436944
# 0.0394425829872489 0.01722843130119145
# 0.03966375486925244 0.017241001361981034
# 0.040042098611593246 0.017042369348928332
# 0.03953924495726824 0.01686649303883314
# 0.03946231445297599 0.016946894582360983
# 0.039224719163030386 0.016709929099306464
# 0.03947383537888527 0.016564400400966406
# 0.03973451256752014 0.016680905362591147
# 0.03909360431134701 0.016708906972780824
# 0.03972658794373274 0.016663629561662674
# 0.03911816095933318 0.016278190538287163
# 0.03930571023374796 0.016200628597289324
# 0.03953606216236949 0.016536116134375334
# 0.0394522282294929 0.016573132015764713
# 0.039647042751312256 0.0169856536667794
# 0.03958055516704917 0.016519528813660145
# 0.04002782655879855 0.016394510865211487
# 0.03982741478830576 0.01642299396917224
# 0.03969691041857004 0.016112100798636675
# 0.039762860629707575 0.016721396706998348
# 0.03898759791627526 0.016147132497280836
# 0.039295928087085485 0.016770991263911128
# 0.03992611635476351 0.016173271229490638
# 0.0398883274756372 0.01585583877749741
# 0.04033752344548702 0.015842726919800043
# 0.03942521754652262 0.01637403480708599
# 0.039722131099551916 0.016106069553643465
# 0.03986879298463464 0.016639571404084563
# 0.03965317364782095 0.015984242549166083
# 0.040517253801226616 0.0157930098939687
# 0.04005698440596461 0.01582159288227558
# 0.03978634811937809 0.015653501264750957
# 0.03979699220508337 0.015730003360658884
# 0.039642490446567535 0.016793710412457585
# 0.03964192094281316 0.017712995409965515
# 0.03999492758885026 0.016061585629358888
# 0.04032190516591072 0.016223515383899212
# 0.03958878247067332 0.016494744922965765
# 0.040092213079333305 0.015763003611937165
# 0.03997149085626006 0.016246548853814602
# 0.03947784751653671 0.01580895995721221
# 0.03985282173380256 0.015639047138392925
# 0.03976042242720723 0.015883804531767964
# 0.03967924928292632 0.015743838157504797
# 0.040250346064567566 0.015724452678114176
# 0.03966017113998532 0.016194848343729973
# 0.03991426806896925 0.015520177315920591
# 0.03958878759294748 0.01620998396538198
# 0.040279706940054893 0.016165635781362653
# 0.04002258041873574 0.015747126657515764
# 0.0403779917396605 0.016004617093130946
# 0.03966935444623232 0.01625853474251926
# 0.03956977371126413 0.01564877014607191
# 0.039699697867035866 0.015517159597948194
# 0.03994987299665809 0.01612947159446776
# 0.03939514001831412 0.015483628027141094
# 0.03990097576752305 0.015477909240871668
# 0.04034850839525461 0.01543537457473576
# 0.03985236072912812 0.015940771205350757
# 0.039503981824964285 0.015681974356994033
# 0.03947706567123532 0.0157251360360533
# 0.03985245665535331 0.015778715256601572
# 0.03996924264356494 0.015505015151575208
# 0.03996733669191599 0.015343296574428678
# 0.040481455624103546 0.016099713277071714
# 0.04003723198547959 0.01570174959488213
# 0.0395693713799119 0.01548958825878799
# 0.0399335459806025 0.01579358638264239
# 0.03960058931261301 0.015496229752898216
# 0.04006660496816039 0.01567725115455687
# 0.04012896679341793 0.015406725695356727
# 0.040371010545641184 0.015436634654179215
# 0.0397027675062418 0.015983849996700883
# 0.03963725175708532 0.015530977863818407
# 0.03992699133232236 0.015279702609404922
# 0.03993265796452761 0.01593560352921486
# 0.0402181982062757 0.015299130231142044
# 0.04015440167859197 0.01529493578709662
# 0.03954323893412948 0.015420719748362899
# 0.039684522431343794 0.016022494761273265
# 0.04017596784979105 0.016188269248232245
# 0.04009609343484044 0.015393424546346068
# 0.04033108800649643 0.015529724769294262
# 0.04042654670774937 0.01534390076994896
# 0.0404327055439353 0.01568782120011747
# 0.039834776893258095 0.015397617593407631
# 0.03969908086583018 0.015308525646105409
# 0.039442905690521 0.015208316268399358
# 0.03994845785200596 0.015131690772250295
# 0.03953438391909003 0.01540901092812419
# 0.039723473601043224 0.01627355976961553
# 0.040104235988110304 0.01598556968383491
# 0.039882419630885124 0.015149748884141445
# 0.040075268130749464 0.016229868168011308
# 0.04045487055554986 0.015422386582940817
# 0.03988651977851987 0.015305107459425926
# 0.03992317384108901 0.015219781314954162
# 0.039986627176404 0.015132516389712691
# 0.04046932188794017 0.01617377414368093
# 0.04026466328650713 0.015311603201553226
# 0.03948370087891817 0.016249517910182476
# 0.039918893948197365 0.015536601888015866
# 0.040148118045181036 0.015424844343215227
# 0.03979086363688111 0.015260515501722693
# 0.040240473579615355 0.0160105568356812
# 0.04041895363479853 0.015519677428528666
# 0.040082518476992846 0.015252248151227832
# 0.03975355112925172 0.01528792455792427
# 0.039759531151503325 0.015861069317907095
# 0.0407138136215508 0.015526375966146588
# 0.0397348552942276 0.015433891210705042
# 0.040454255882650614 0.015200236812233925
# 0.04035688238218427 0.015168810030445457
# 0.03949687676504254 0.015240254811942577
# 0.03997855959460139 0.015258203260600567
# 0.039249060209840536 0.01513130753301084
# 0.04084439715370536 0.016523653641343117
# 0.04022454749792814 0.015305147273465991
# 0.04041875572875142 0.015063676051795483
# 0.040232948027551174 0.01572429179213941
# 0.04032167000696063 0.015548473689705133
# 0.03997707553207874 0.015612736577168107
# 0.03986557712778449 0.015352499671280384
# 0.03977308003231883 0.015424402663484216
# 0.0400813827291131 0.015328258974477649
# 0.03998704580590129 0.01575269061140716
# 0.039820896461606026 0.015473561361432076
# 0.040550087578594685 0.015538382809609175
# 0.039986321702599525 0.015424367506057024
# 0.03996891900897026 0.015299991704523563
# 0.03968113800510764 0.015153382439166307
# 0.040217009373009205 0.015083443140611053
# 0.04032397968694568 0.01566586666740477
# 0.04012009594589472 0.015297975158318877
# 0.040434890892356634 0.015251035802066326
# 0.04030996048822999 0.015349213732406497
# 0.04031094582751393 0.015730823623016477
# 0.03997041005641222 0.015306910732761025
# 0.04017122322693467 0.015087062725797296
# 0.03981458814814687 0.01523218653164804
# 0.03995245136320591 0.015712604159489274
# 0.040134941693395376 0.015586841152980924
# 0.04022206366062164 0.01561876223422587
# 0.039353364147245884 0.01594306412152946
# 0.04039661679416895 0.01577879791148007
# 0.03976493515074253 0.015096054645255208
# 0.03950586449354887 0.015080671524628997
# 0.039920622017234564 0.015129396226257086
# 0.04002216225489974 0.015129791805520654
# 0.039719824213534594 0.015271542826667428
# 0.03984394622966647 0.015255796257406473
# 0.039264746475964785 0.01583117013797164
# 0.04017619416117668 0.015287704765796661
# 0.040251629427075386 0.015098314266651869
# 0.040014561265707016 0.015021596336737275
# 0.03994979429990053 0.014949443051591516
# 0.03971605421975255 0.01604393753223121
# 0.040544926188886166 0.015773116145282984
# 0.03961635334417224 0.014936736319214106
# 0.039801848120987415 0.015600573038682342
# 0.04031113348901272 0.01531909010373056
# 0.041026214603334665 0.015383820282295346
# 0.04016423039138317 0.015298539772629738
# 0.040434959810227156 0.01502844225615263
# 0.039982568472623825 0.015069216722622514
# 0.04048514924943447 0.015377953415736556
# 0.04015360865741968 0.015322062186896801
# 0.03989685792475939 0.015156776644289494
# 0.0398739343509078 0.015279979445040226
# 0.04023987706750631 0.015020712278783321
# 0.0399781814776361 0.014977345708757639
# 0.04032439598813653 0.014937275787815452
# 0.040248583536595106 0.014960892731323838
# 0.039749538991600275 0.015849765157327056
# 0.04054993810132146 0.015644056256860495
# 0.03998646233230829 0.015222052112221718
# 0.03980899089947343 0.014947749674320221
# 0.040844399482011795 0.015410547377541661
# 0.04037124291062355 0.015267192851752043
# 0.03975136578083038 0.01540043344721198
# 0.03962726378813386 0.015552802011370659
# 0.040123780723661184 0.014957651728764176
# 0.040136702824383974 0.015031978487968445
# 0.03995045693591237 0.01544977119192481
# 0.03975436929613352 0.015584773849695921
# 0.04022172698751092 0.015498727560043335
# 0.04036781657487154 0.015828329836949706
# 0.039607899729162455 0.015753060346469283
# 0.04020630707964301 0.014962385408580303
# 0.04034930979833007 0.015104075195267797
# 0.039917043410241604 0.015187741722911596
# 0.040224216878414154 0.015339190373197198
# 0.04009992862120271 0.01591512095183134
# 0.040220883674919605 0.015419705072417855
# 0.040334177669137716 0.015321705490350723
# 0.040556502528488636 0.01606102380901575
# 0.03989632474258542 0.015709916362538934
# 0.040431355591863394 0.014948490774258971
# 0.04027111874893308 0.015018125530332327
# 0.040280938148498535 0.01591423130594194
# 0.04044297197833657 0.015452568186447024
# 0.03970782412216067 0.015187420649453998
# 0.040191806852817535 0.015526006696745753
# 0.03958507627248764 0.015348240500316024
# 0.04013995872810483 0.01515523949638009
# 0.04038553452119231 0.015147694386541843
# 0.03971860045567155 0.015052800066769123
# 0.040175536181777716 0.014917463064193726
# 0.039829210843890905 0.01502638915553689
# 0.039784569293260574 0.015926813473924994
# 0.039429102558642626 0.015258513391017914
# 0.040096553042531013 0.014969389420002699
# 0.04011484142392874 0.01496086292900145
# 0.04028951842337847 0.01556465937756002
# 0.03995404997840524 0.015239654341712594
# 0.040157269686460495 0.015102282399311662
# 0.039531122893095016 0.015048475004732609
# 0.039837471675127745 0.01492361119017005
# 0.03977477317675948 0.01530562061816454
# 0.04048206564038992 0.015472720377147198
# 0.04024626035243273 0.015228365547955036
# 0.04027190990746021 0.015184531453996897
# 0.040160033386200666 0.015058733522891998
# 0.039561023470014334 0.014976614154875278
# 0.04071439104154706 0.015010217437520623
# 0.04010115657001734 0.014953974401578307
# 0.03965245001018047 0.014909566845744848
# 0.04008809570223093 0.01565621281042695
# 0.04039269592612982 0.015393543289974332
# 0.03981628268957138 0.014951137825846672
# 0.040169624611735344 0.014988447073847055
# 0.04002554854378104 0.014934869017452002
# 0.04011173686012626 0.014907341683283448
# 0.04060540487989783 0.01486243773251772
# 0.03981624590232968 0.01484482898376882
# 0.04000794282183051 0.015368240885436535
# 0.040003574918955564 0.015402234392240644
# 0.04025828652083874 0.01517381682060659
# 0.03970446763560176 0.015151346335187554
# 0.040007532108575106 0.01518394728191197
# 0.04045981355011463 0.015136143192648888
# 0.039767530746757984 0.015127676771953702
# 0.039518374018371105 0.015037627192214131
# 0.040232306346297264 0.015096445800736547
# 0.04005822306498885 0.014936959370970726
# 0.040137914940714836 0.014934913953766227
# 0.03987071942538023 0.015508062904700637
# 0.04032742092385888 0.015316163655370474
# 0.039796368684619665 0.015218888875097036
# 0.010769960470497608 0.16898137424141169
# 0.011088198516517878 0.15821321122348309
# 0.011237516649998724 0.15160321071743965
# 0.011237490107305348 0.14711381122469902
# 0.011471373029053211 0.1447063097730279
# 0.011564022046513855 0.14343927334994078
# 0.011447024182416499 0.14315080642700195
# 0.011683774180710316 0.1430552313104272
# 0.011624742648564279 0.14278197847306728
# 0.011735348380170763 0.14243312552571297
# 0.011644786223769188 0.14201717637479305
# 0.011562611791305244 0.141731770709157
# 0.011518077808432281 0.1414211941882968
# 0.011590184411033988 0.1409967252984643
# 0.011745816795155406 0.14069326128810644
# 0.011712271021679044 0.14034865610301495
# 0.011554139433428645 0.13992185052484274
# 0.011627042898908257 0.13962991628795862
# 0.011848198133520782 0.13932972494512796
# 0.011945635080337524 0.1389079289510846
# 0.011859000893309712 0.13848565891385078
# 0.01189928106032312 0.1382069354876876
# 0.011946940911002457 0.1378275090828538
# 0.012129926471970975 0.13743130397051573
# 0.012176315882243216 0.13694769423455
# 0.012365985312499106 0.13660066667944193
# 0.012255814392119646 0.13618202786892653
# 0.012327698641456664 0.13581055402755737
# 0.012444167281500995 0.1353445379063487
# 0.012537564733065665 0.1348384078592062
# 0.012747498461976647 0.1343812383711338
# 0.012715034652501345 0.1339484928175807
# 0.012955822166986763 0.13349891919642687
# 0.013049853383563459 0.13295865152031183
# 0.013387478538788855 0.1324988529086113
# 0.013245814363472164 0.13205447420477867
# 0.013553209719248116 0.1314507694914937
# 0.013544501503929496 0.1309357052668929
# 0.013667718973010778 0.13039606343954802
# 0.013976808986626565 0.12981732934713364
# 0.014183743740431964 0.12915797997266054
# 0.01434729213360697 0.12856111209839582
# 0.014446877292357385 0.1279545621946454
# 0.014510032837279141 0.12722255196422338
# 0.014840010786429048 0.12661041412502527
# 0.01508177479263395 0.1259271577000618
# 0.015443178708665073 0.12517978809773922
# 0.015393365290947258 0.12437811680138111
# 0.015516245388425887 0.123621572740376
# 0.015728664468042552 0.12295692041516304
# 0.01604509726166725 0.12210097629576921
# 0.01621876109857112 0.1211601858958602
# 0.016465453896671534 0.12026844546198845
# 0.01674671098589897 0.1193796144798398
# 0.01703679282218218 0.11838580016046762
# 0.01717623951844871 0.1175382575020194
# 0.01744607789441943 0.11669779103249311
# 0.017744845477864146 0.11580289527773857
# 0.01799505902454257 0.11496773734688759
# 0.018123878398910165 0.11410837713629007
# 0.018385159317404032 0.11315812636166811
# 0.018688017735257745 0.11225496418774128
# 0.0188005396630615 0.11147075798362494
# 0.019210459431633353 0.11055026017129421
# 0.019432885106652975 0.10945623554289341
# 0.019723617704585195 0.10850304923951626
# 0.019781962037086487 0.1075763925909996
# 0.02043451159261167 0.10636904323473573
# 0.020196271128952503 0.10528774606063962
# 0.020621354691684246 0.10439800610765815
# 0.021107578184455633 0.10325264325365424
# 0.02100946311838925 0.10226503340527415
# 0.021378769539296627 0.10116195399314165
# 0.021624579560011625 0.1000184970907867
# 0.021981132682412863 0.09884509164839983
# 0.022349792532622814 0.09775588847696781
# 0.022484527667984366 0.09659753367304802
# 0.022624575067311525 0.09545357013121247
# 0.022946825250983238 0.09410551516339183
# 0.02313859830610454 0.09282663324847817
# 0.02380165783688426 0.09149644942954183
# 0.023676251294091344 0.0904793762601912
# 0.02395551512017846 0.08920240914449096
# 0.02405319409444928 0.08782378071919084
# 0.024768537608906627 0.08687096741050482
# 0.024847483029589057 0.08574134530499578
# 0.025128409266471863 0.08486260008066893
# 0.024769379990175366 0.08367809094488621
# 0.025304484646767378 0.0827009305357933
# 0.025851501850411296 0.08144286787137389
# 0.025853606406599283 0.08034245576709509
# 0.0265877319034189 0.07935207057744265
# 0.02647325722500682 0.07847798755392432
# 0.02703166869468987 0.0773107330314815
# 0.02698273677378893 0.07657523592934012
# 0.026778859784826636 0.07555808732286096
# 0.026923644356429577 0.07432361971586943
# 0.027074299287050962 0.0734986481256783
# 0.027043321635574102 0.07268592808395624
# 0.02772409562021494 0.07191634410992265
# 0.0276788379997015 0.07095238752663136
# 0.028352903900668025 0.06972558982670307
# 0.028467909898608923 0.06884692842140794
# 0.028519733576104045 0.06804955750703812
# 0.028634537709876895 0.0669147721491754
# 0.02874580817297101 0.06600454356521368
# 0.029688802547752857 0.06495152600109577
# 0.029454096918925643 0.06440098164603114
# 0.02971695247106254 0.06311485962942243
# 0.029584179632365704 0.062109014950692654
# 0.03030976513400674 0.06132260523736477
# 0.030155673623085022 0.060771350748836994
# 0.030173331266269088 0.059341274201869965
# 0.030371914384886622 0.0588777344673872
# 0.03091126517392695 0.058457260485738516
# 0.030963448341935873 0.056610568426549435
# 0.031407994916662574 0.05661910166963935
# 0.03110000886954367 0.05543690361082554
# 0.03111500176601112 0.054212273098528385
# 0.031525881960988045 0.05369234411045909
# 0.03214149456471205 0.05267436010763049
# 0.0320575968362391 0.051496701780706644
# 0.03184159775264561 0.05138078145682812
# 0.03231714107096195 0.049784417264163494
# 0.03178038611076772 0.04996061138808727
# 0.032761248759925365 0.048820300959050655
# 0.03259847825393081 0.04720123903825879
# 0.03268284210935235 0.047310459427535534
# 0.03312605805695057 0.04626030474901199
# 0.032730717211961746 0.044826861936599016
# 0.0334915928542614 0.04444884276017547
# 0.03359783720225096 0.0432812487706542
# 0.03396657994017005 0.04290530737489462
# 0.03357911203056574 0.04220952093601227
# 0.033775472082197666 0.04086189670488238
# 0.03404127759858966 0.04028629371896386
# 0.03462295979261398 0.039958018343895674
# 0.03401008667424321 0.03895424725487828
# 0.03470780095085502 0.03901919210329652
# 0.034096496645361185 0.03741897223517299
# 0.03393437899649143 0.037120142951607704
# 0.03507238253951073 0.036105175036937
# 0.03490815404802561 0.03546863002702594
# 0.03512413986027241 0.034906679298728704
# 0.035308494698256254 0.034480387810617685
# 0.03550061583518982 0.03355575818568468
# 0.03549330402165651 0.03336783219128847
# 0.03522847592830658 0.03240310261026025
# 0.03545902902260423 0.03232342330738902
# 0.03564430493861437 0.031566180754452944
# 0.03572193346917629 0.03142976248636842
# 0.03560292115435004 0.030434675980359316
# 0.036030201241374016 0.030783735681325197
# 0.03603882296010852 0.030011755414307117
# 0.0365191618911922 0.0302221376914531
# 0.03620510222390294 0.029292702209204435
# 0.036220832262188196 0.02952084969729185
# 0.036490161903202534 0.028496989980340004
# 0.03625777689740062 0.028582831844687462
# 0.03671299712732434 0.02812558296136558
# 0.03648796025663614 0.027596038533374667
# 0.03685164591297507 0.026990394573658705
# 0.03598257387056947 0.027070421259850264
# 0.0374414436519146 0.02682697237469256
# 0.0369631452485919 0.026608915766701102
# 0.03655836405232549 0.026338418712839484
# 0.03715417813509703 0.026831180788576603
# 0.036535021383315325 0.02643885836005211
# 0.037095768842846155 0.02792309899814427
# 0.03761321911588311 0.0275012431666255
# 0.037158646155148745 0.028229153947904706
# 0.03785688616335392 0.026349842315539718
# 0.03691964643076062 0.02679861127398908
# 0.03765171766281128 0.026363897137343884
# 0.037697719875723124 0.027380326995626092
# 0.037600849755108356 0.0252444373909384
# 0.038494907319545746 0.025313609978184104
# 0.03766793617978692 0.024895100621506572
# 0.03758823638781905 0.023848900804296136
# 0.0377140580676496 0.024007422849535942
# 0.03794538788497448 0.02288803644478321
# 0.038147622253745794 0.022623839555308223
# 0.03779455740004778 0.02259043836966157
# 0.03796287113800645 0.022408128017559648
# 0.03718516370281577 0.022046785801649094
# 0.03789254417642951 0.02173125697299838
# 0.03800154384225607 0.021270035998895764
# 0.038078595884144306 0.021593583980575204
# 0.038379911333322525 0.02049627644009888
# 0.038537018932402134 0.02090474800206721
# 0.038212718442082405 0.020921330200508237
# 0.03815335454419255 0.020941856550052762
# 0.038277899380773306 0.020449186908081174
# 0.03840847406536341 0.021095558535307646
# 0.03878134302794933 0.020866695092990994
# 0.03837227821350098 0.020045937737450004
# 0.03855488542467356 0.020106507232412696
# 0.037938912864774466 0.01969211152754724
# 0.038379722740501165 0.019771542865782976
# 0.03855819860473275 0.01989780063740909
# 0.03823584411293268 0.019634368596598506
# 0.038142670411616564 0.019263460068032146
# 0.03872826183214784 0.020552702015265822
# 0.03830132260918617 0.020972810685634613
# 0.038799168076366186 0.020101753994822502
# 0.03854733798652887 0.02009457629173994
# 0.03843257948756218 0.01951854443177581
# 0.03901838604360819 0.01912897126749158
# 0.03839632635936141 0.01865737373009324
# 0.038149101193994284 0.01848370279185474
# 0.03828890481963754 0.019371240865439177
# 0.038644730579108 0.018582185031846166
# 0.03885016730055213 0.01851920271292329
# 0.03894177312031388 0.018472323892638087
# 0.0384321422316134 0.017956291558220983
# 0.03918607672676444 0.017734017921611667
# 0.03800898836925626 0.018185952911153436
# 0.03814592491835356 0.01868661935441196
# 0.03823829721659422 0.01816337346099317
# 0.03857249300926924 0.01821768842637539
# 0.03886808827519417 0.018027316080406308
# 0.03881972189992666 0.017760001122951508
# 0.038922980427742004 0.01854087389074266
# 0.0386983253993094 0.01873221341520548
# 0.03836447140201926 0.018260681070387363
# 0.03977499529719353 0.018342310562729836
# 0.03892161324620247 0.017986564664170146
# 0.03909558104351163 0.01740942313335836
# 0.03913720231503248 0.018199371173977852
# 0.03912662481889129 0.017700335243716836
# 0.03946742322295904 0.017345853382721543
# 0.03891218872740865 0.017583570908755064
# 0.03919928567484021 0.017735311528667808
# 0.03891105204820633 0.017853422788903117
# 0.03911625919863582 0.017277418402954936
# 0.03868357324972749 0.01723399991169572
# 0.0389053407125175 0.01725267991423607
# 0.03892431315034628 0.01740904082544148
# 0.0392351052723825 0.017336041433736682
# 0.03918746905401349 0.01685779937542975
# 0.039352890104055405 0.01766136917285621
# 0.03890357306227088 0.017253186320886016
# 0.03895526099950075 0.01746572693809867
# 0.03910694271326065 0.017646568128839135
# 0.03910639276728034 0.01760732172988355
# 0.039433843456208706 0.01722144428640604
# 0.03880482306703925 0.01735490676946938
# 0.039281655102968216 0.016740367515012622
# 0.03961718361824751 0.017417480237782
# 0.03902305057272315 0.017287458758801222
# 0.03926174156367779 0.01666003791615367
# 0.03887468343600631 0.017118236981332302
# 0.039245419669896364 0.01702065789140761
# 0.03869609860703349 0.017266229260712862
# 0.0391950742341578 0.01688049384392798
# 0.03940835269168019 0.016532575711607933
# 0.03891780273988843 0.016934938728809357
# 0.03941757744178176 0.016842449083924294
# 0.03898735856637359 0.016604460077360272
# 0.03945479867979884 0.016713813180103898
# 0.039579326286911964 0.016627160366624594
# 0.039432975463569164 0.01713321590796113
# 0.03920462680980563 0.01765888393856585
# 0.039279844146221876 0.016383356414735317
# 0.04014382418245077 0.017010433366522193
# 0.039822610560804605 0.016485588625073433
# 0.039076704531908035 0.016605413984507322
# 0.03967759758234024 0.015686267521232367
# 0.03919780720025301 0.016478920122608542
# 0.038548790384083986 0.016940904315561056
# 0.03933265712112188 0.017107397550716996
# 0.03899133438244462 0.016743818297982216
# 0.03881853772327304 0.016703694593161345
# 0.03888841159641743 0.016645552590489388
# 0.039250670466572046 0.0164027928840369
# 0.03941914904862642 0.01659239735454321
# 0.03956117806956172 0.016579359769821167
# 0.039516684133559465 0.016627159668132663
# ...
# 0.012428866582922637 0.11425082758069038
# 0.012315506697632372 0.11377284303307533
# 0.012383025139570236 0.11325314175337553
# 0.012543132877908647 0.11286729667335749
# 0.012503845733590424 0.11231715511530638
# 0.012900814646854997 0.11186112929135561
# 0.012736112461425364 0.11142356880009174
# 0.013034675270318985 0.11091074254363775
# 0.012967012356966734 0.11034931149333715
# 0.012890564044937491 0.10994185972958803
# 0.013418867834843695 0.10936211422085762
# 0.01315526687540114 0.10887942928820848
# 0.013355583301745355 0.10840841103345156
# 0.013453878462314606 0.10779308807104826
# 0.013503092341125011 0.10725033283233643
# 0.013663644320331514 0.10666412301361561
# 0.01368821319192648 0.10625556204468012
# 0.013894087634980679 0.10553740803152323
# 0.013930250308476388 0.10490863770246506
# 0.013907664571888745 0.1043087113648653
# 0.01412270707078278 0.10380677226930857
# 0.01438238995615393 0.1032531475648284
# 0.014333203318528831 0.10255948826670647
# 0.014180845464579761 0.10194873809814453
# 0.014323641080409288 0.10149995516985655
# 0.014493180788122118 0.10066211130470037
# 0.014677971368655562 0.10005640983581543
# 0.014793625450693071 0.09936833288520575
# 0.015081817982718349 0.09861108660697937
# 0.014980295323766768 0.09811097476631403
# 0.015124065335839987 0.09725154750049114
# 0.015256107086315751 0.0966178746894002
# 0.015185517375357449 0.0960123697295785
# 0.015377571573480964 0.09510706923902035
# 0.01590789621695876 0.09446840267628431
# 0.01600961748044938 0.09367621317505836
# 0.015709532308392227 0.09288139175623655
# 0.01616031478624791 0.09208845999091864
# 0.0159927518106997 0.09127649944275618
# 0.016017540940083563 0.09046558942645788
# 0.016474908916279674 0.08978433348238468
# 0.016479721758514643 0.0888654962182045
# 0.016360566718503833 0.08814762718975544
# 0.016786577412858605 0.08734794985502958
# 0.017046475782990456 0.0864187702536583
# 0.017204955918714404 0.0855049192905426
# 0.01692127250134945 0.0847106808796525
# 0.017175118438899517 0.08396693412214518
# 0.017191443359479308 0.08290790766477585
# 0.017701849108561873 0.08198931626975536
# 0.017610049340873957 0.08114413358271122
# 0.017778426175937057 0.08026773296296597
# 0.017749644117429852 0.0791144766844809
# 0.018254501977935433 0.07849187590181828
# 0.01816797978244722 0.07732157595455647
# 0.01849803444929421 0.07670061057433486
# 0.018777201185002923 0.07576175546273589
# 0.018702383851632476 0.07479852624237537
# 0.018960728542879224 0.0737180095165968
# 0.019290338503196836 0.07273728074505925
# 0.019087150460109115 0.07149406289681792
# 0.019185037119314075 0.07067795051261783
# 0.019362953724339604 0.0700262007303536
# 0.019701970973983407 0.06865708343684673
# 0.01971440901979804 0.06786694144830108
# 0.019655478186905384 0.06693909363821149
# 0.020001365803182125 0.06602784804999828
# 0.020336066838353872 0.06496929563581944
# 0.02000057464465499 0.06409402936697006
# 0.02049013669602573 0.06380649982020259
# 0.020589554216712713 0.06241662288084626
# 0.020638480549678206 0.06165638752281666
# 0.020798325072973967 0.06096509378403425
# 0.0209095177706331 0.06034372607246041
# 0.020792165072634816 0.0594654050655663
# 0.021317316219210625 0.05854596383869648
# 0.021283401641994715 0.05841143662109971
# 0.021559470798820257 0.057298630475997925
# 0.021614373894408345 0.056218769401311874
# 0.021620920160785317 0.05570919159799814
# 0.021588256116956472 0.05519431456923485
# 0.021779164904728532 0.05452061723917723
# 0.021892263321205974 0.0541003942489624
# 0.021979917073622346 0.05277342861518264
# 0.021760323783382773 0.05263219866901636
# 0.022429432021453977 0.051214929204434156
# 0.022693398874253035 0.051332673989236355
# 0.02238851902075112 0.049997853580862284
# 0.02215733495540917 0.050053722225129604
# 0.02283668890595436 0.048822734504938126
# 0.023140083998441696 0.04873234964907169
# 0.022582937963306904 0.047684239223599434
# 0.022715885192155838 0.04732808331027627
# 0.02303975634276867 0.04629824589937925
# 0.023096302757039666 0.04649081593379378
# 0.02283517806790769 0.04508958291262388
# 0.023097993806004524 0.04533468373119831
# 0.023711373331025243 0.04406055808067322
# 0.02331164269708097 0.04441063851118088
# 0.02368670143187046 0.04306929651647806
# 0.02356381854042411 0.042710320092737675
# 0.023705125553533435 0.04162685852497816
# 0.023720571538433433 0.04218534240499139
# 0.02404354396276176 0.040817050728946924
# 0.023870510049164295 0.04132902668789029
# 0.024452543118968606 0.04014034103602171
# 0.02396336430683732 0.03994547575712204
# 0.02417775266803801 0.038823455572128296
# 0.024379678536206484 0.03861812734976411
# 0.02476220205426216 0.03768148412927985
# 0.02451395452953875 0.03738993452861905
# 0.02428203821182251 0.03701789118349552
# 0.0242762656416744 0.03646059287711978
# 0.02453762572258711 0.036467806436121464
# 0.024815175449475646 0.035317549016326666
# 0.024756686063483357 0.03568766498938203
# 0.024548333836719394 0.03447879757732153
# 0.024442863883450627 0.036688091699033976
# 0.025182063691318035 0.03462089132517576
# 0.024840379832312465 0.034758569207042456
# 0.025199171854183078 0.03343661781400442
# 0.025184902595356107 0.0334552014246583
# 0.02563668298535049 0.03268220275640488
# 0.025038642808794975 0.032729732571169734
# 0.025026348419487476 0.03180146892555058
# 0.025416883174329996 0.03176961210556328
# 0.025450774934142828 0.031512123765423894
# 0.025391616625711322 0.031556289410218596
# 0.026012472109869123 0.030194575432687998
# 0.025548806646838784 0.030374195659533143
# 0.025529068894684315 0.029748142696917057
# 0.025520855095237494 0.03010391304269433
# 0.02600914821960032 0.028838670579716563
# 0.02565304492600262 0.028509208466857672
# 0.025699922814965248 0.028494715923443437
# 0.025821821531280875 0.028888059314340353
# 0.02549129375256598 0.02784795593470335
# 0.0257261642254889 0.027925512520596385
# 0.025942593812942505 0.027017562184482813
# 0.02636434370651841 0.026723840506747365
# 0.026626278646290302 0.026343047618865967
# 0.026503722416236997 0.027086203219369054
# 0.02603301638737321 0.02593987970612943
# 0.02612622594460845 0.026226884219795465
# 0.026417999295517802 0.02533304807730019
# 0.026062155608087778 0.02543758344836533
# 0.026069111423566937 0.025022082729265094
# 0.026280302554368973 0.024623032193630934
# 0.026526074158027768 0.0242828952614218
# 0.026538986479863524 0.024025260703638196
# 0.026541523169726133 0.02347958809696138
# 0.02627406967803836 0.023093860829249024
# 0.0267739943228662 0.02321094647049904
# 0.02665609889663756 0.022954903775826097
# 0.02710958570241928 0.022620856063440442
# 0.02689663995988667 0.023351144744083285
# 0.02707232953980565 0.022053304128348827
# 0.026527166133746505 0.022173434728756547
# 0.026750171091407537 0.02133129769936204
# 0.027037894120439887 0.021502459421753883
# 0.02688145567663014 0.021116032963618636
# 0.026844354113563895 0.02147112926468253
# 0.02694570948369801 0.020704901544377208
# 0.02685714396648109 0.020207787165418267
# 0.027330356650054455 0.020349200582131743
# 0.027019219007343054 0.02056684996932745
# 0.02702525514177978 0.019886288791894913
# 0.02736019715666771 0.02012446033768356
# 0.026973241940140724 0.020095395855605602
# 0.027066959533840418 0.020209225127473474
# 0.027271036291494966 0.019300426822155714
# 0.027138349134474993 0.019904742250218987
# 0.02747703460045159 0.019876840757206082
# 0.027345639187842607 0.019458350026980042
# 0.027514518005773425 0.019215091597288847
# 0.027072099037468433 0.019085486652329564
# 0.027314187958836555 0.01889544236473739
# 0.026977316942065954 0.0186270191334188
# 0.026996327796950936 0.019055225420743227
# 0.027579793008044362 0.01804100605659187
# 0.026760227512568235 0.018629748607054353
# 0.02718685520812869 0.018542119301855564
# 0.027798797702416778 0.0185688107740134
# 0.02767711505293846 0.018217591335996985
# 0.02732205158099532 0.018233813112601638
# 0.027437965851277113 0.018524718936532736
# 0.02727569965645671 0.019394354661926627
# 0.027381058782339096 0.01921415259130299
# 0.027512483531609178 0.01982590346597135
# 0.027592979837208986 0.0184776799287647
# 0.027559563284739852 0.018230969784781337
# 0.02768161310814321 0.018188825342804193
# 0.027354670222848654 0.018021668773144484
# 0.02772192400880158 0.01762861432507634
# 0.02722971560433507 0.01799750211648643
# 0.027547880308702588 0.017832275480031967
# 0.027621290646493435 0.0182500253431499
# 0.027741458034142852 0.018271318869665265
# 0.02777339913882315 0.017776303691789508
# 0.02798174717463553 0.01714107464067638
# 0.02791855577379465 0.01764320069923997
# 0.027679090620949864 0.017489272635430098
# 0.027637545485049486 0.017833499936386943
# 0.027537860674783587 0.017363816499710083
# 0.02778772101737559 0.01770734926685691
# 0.02766463253647089 0.017313837073743343
# 0.027509362436830997 0.017642985098063946
# 0.027588704135268927 0.017848962917923927
# 0.027314378414303064 0.017602070467546582
# 0.027997454861178994 0.01743711670860648
# 0.028107133228331804 0.01783047942444682
# 0.027979291044175625 0.01762098097242415
# 0.027651514625176787 0.017357720993459225
# 0.02786199515685439 0.017029104521498084
# 0.027976475888863206 0.017439116025343537
# 0.027507698396220803 0.017602187348529696
# 0.027630179189145565 0.017403157893568277
# 0.02790972264483571 0.017374426824972034
# 0.027816035551950336 0.017193794948980212
# 0.02751025347970426 0.017099377466365695
# 0.028160544577986002 0.017681612633168697
# 0.02780601428821683 0.017528537660837173
# 0.02791188657283783 0.017264709575101733
# 0.02789790043607354 0.017147694481536746
# 0.027651118813082576 0.017028201138600707
# 0.02794475294649601 0.017026958987116814
# 0.02784286765381694 0.016980675281956792
# 0.028125185752287507 0.016866017132997513
# 0.028218878898769617 0.017730446066707373
# 0.02798238513059914 0.01779077365063131
# 0.028099170653149486 0.016787561122328043
# 0.02771230973303318 0.01692703878507018
# 0.027959887171164155 0.01729938550852239
# 0.02785035059787333 0.0170628831256181
# 0.027874111430719495 0.017232446698471904
# 0.028253646101802588 0.017306745052337646
# 0.027990521164610982 0.016719795763492584
# 0.027823703130707145 0.017433072673156857
# 0.027682623825967312 0.017591357696801424
# 0.02773571410216391 0.016983971465379
# 0.027798831462860107 0.01643039984628558
# 0.027817517518997192 0.016904811142012477
# 0.027742776786908507 0.017104627331718802
# 0.02734907530248165 0.016889505088329315
# 0.027834354201331735 0.016530930064618587
# 0.028214077465236187 0.017498271074146032
# 0.02747390209697187 0.017129283398389816
# 0.02807166031561792 0.016985915368422866
# 0.02760769729502499 0.017038742313161492
# 0.027435955591499805 0.0169514084700495
# 0.028241197112947702 0.01777260354720056
# 0.02832072228193283 0.016490237088873982
# 0.027819941053166986 0.01724068820476532
# 0.027336249127984047 0.016982707660645247
# 0.027832311345264316 0.01679325453005731
# 0.027935144491493702 0.016415765043348074
# 0.027800378389656544 0.016720525920391083
# 0.0274517722427845 0.016401107655838132
# 0.027520279167219996 0.016971121076494455
# 0.028053237358108163 0.01671936991624534
# 0.027952302247285843 0.01736636273562908
# 0.027730271918699145 0.01716760382987559
# 0.027760946890339255 0.016830870881676674
# 0.028130344580858946 0.01650050817988813
# 0.027574829291552305 0.016716453013941646
# 0.027789989486336708 0.016754429787397385
# 0.027948618633672595 0.01653760438784957
# 0.028344160178676248 0.01681349496357143
# 0.02726952498778701 0.016802988247945905
# 0.02778095519170165 0.016428304370492697
# 0.028360452968627214 0.016862034797668457
# 0.028076328802853823 0.01640957430936396
# 0.02778044599108398 0.016509993001818657
# 0.027597226202487946 0.016787391155958176
# 0.02796076494269073 0.016042024362832308
# 0.027904411545023322 0.016084797447547317
# 0.027948279632255435 0.016007001046091318
# 0.028127797413617373 0.016518832417204976
# 0.028484526090323925 0.016645873431116343
# 0.027570378500968218 0.016803635749965906
# 0.02794843027368188 0.016392707591876388
# 0.027730803238227963 0.017175085376948118
# 0.028094213688746095 0.016743844375014305
# 0.028423009673133492 0.01641664607450366
# 0.02747247484512627 0.016940885689109564
# 0.027937179431319237 0.01612505060620606
# 0.02757446886971593 0.017443126533180475
# 0.028136213775724173 0.016615491127595305
# 0.027458859141916037 0.017754046246409416
# 0.028405602322891355 0.017088780412450433
# 0.027887489646673203 0.017186098732054234
# 0.028015849879011512 0.016540026059374213
# 0.02801959915086627 0.016300756484270096
# 0.02809506724588573 0.016498709795996547
# 0.027985773980617523 0.01632764097303152
# 0.02791500836610794 0.016128374496474862
# 0.02826117188669741 0.016511341091245413
# 0.028028141474351287 0.017580220941454172
# 0.028097511269152164 0.016865959158167243
# 0.02804003586061299 0.017096162773668766
# 0.027848875615745783 0.01652081054635346
# 0.027963196393102407 0.015953888650983572
# 0.027762121055275202 0.016368474811315536
# 0.02751086512580514 0.01651505776681006
# 0.02766131330281496 0.016485635191202164
# 0.027758340584114194 0.01732306438498199
# 0.028259614016860723 0.01619972288608551
# 0.028050341410562396 0.016722013475373387
# 0.028361256467178464 0.016573462402448058
# 0.02765477355569601 0.01801571506075561
# 0.027946952264755964 0.016894024331122637
# 0.02786607458256185 0.01848915871232748
# 0.028028895845636725 0.01685090153478086
# 0.02818222437053919 0.018071341793984175
# 0.028229637537151575 0.017833013320341706
# 0.028118596877902746 0.01887000841088593
# 0.028046488761901855 0.016986457630991936
# 0.028494569938629866 0.01736517413519323
# 0.028153904248028994 0.016769515816122293
# 0.02761101140640676 0.016581580974161625
# 0.027756532421335578 0.016314256703481078
# 0.0277693304233253 0.017847419483587146
# 0.028177908854559064 0.017052204348146915
# 0.027953114826232195 0.017441178672015667
# 0.027736026793718338 0.016798784723505378
# 0.0278098969720304 0.016736048040911555
# 0.027688100235536695 0.016582184936851263
# 0.02768839686177671 0.016972742974758148
# 0.028068973682820797 0.016367896925657988
# 0.028234204975888133 0.017336210468783975
# 0.028376033063977957 0.016160247614607215
# 0.028254237957298756 0.017032081028446555
# 0.027987390756607056 0.016701282933354378
# 0.02842188044451177 0.018284123856574297
# 0.02796958666294813 0.016586453653872013
# 0.028053073678165674 0.017788378288969398
# 0.02775742602534592 0.017136855982244015
# 0.027974908472970128 0.017621659208089113
# 0.02799007552675903 0.016910082194954157
# 0.027860795380547643 0.01728755608201027
# 0.02795067708939314 0.015800603665411472
# 0.02798204217106104 0.01695917220786214
# 0.028061982477083802 0.016101291868835688
# 0.02808761177584529 0.016180699924007058
# 0.027873179642483592 0.016131960321217775
# 0.02787516638636589 0.01624515070579946
# 0.02786662383005023 0.01690071588382125
# 0.027993321185931563 0.015702664386481047
# 0.02823835238814354 0.01613446930423379
# 0.02808892959728837 0.016401041066274047
# 0.028169944183900952 0.01636518072336912
# 0.02812513173557818 0.015788278309628367
# 0.027829577680677176 0.01634830585680902
# 0.02819383074529469 0.015677606221288443
# 0.02784030418843031 0.01644755876623094
# 0.028171222424134612 0.0160310345236212
# 0.02819082629866898 0.016160375904291868
# 0.028010560432448983 0.015931293135508895
# 0.02801342075690627 0.01640906068496406
# 0.02806266164407134 0.015836586244404316
# 0.028243842534720898 0.016352094942703843
# 0.028448633383959532 0.016014639753848314
# 0.027740475488826632 0.01589243020862341
# 0.02782939886674285 0.01606160239316523
# 0.028243214124813676 0.015966553008183837
# 0.028140930458903313 0.015640722354874015
# 0.028042009565979242 0.016487485729157925
# 0.027775941882282495 0.015852604061365128
# 0.027951546711847186 0.016425119480118155
# 0.028362270211800933 0.01635622000321746
# 0.027799150440841913 0.016193245071917772
# 0.028035750379785895 0.0164486113935709
# 0.02818485233001411 0.01570642297156155
# 0.027844078140333295 0.01644421648234129
# 0.02797220880165696 0.016030242666602135
# 0.028105937177315354 0.0157451331615448
# 0.028479951666668057 0.016651707235723734
# 0.028071620035916567 0.016329231206327677
# 0.028320933459326625 0.018065153621137142
# 0.028339893789961934 0.017217121785506606
# 0.028231843141838908 0.017601008526980877
# 0.02801407198421657 0.016364866867661476
# 0.02765683177858591 0.015713673317804933
# 0.028156911488622427 0.016568693099543452
# 0.02808068785816431 0.01580215198919177
# 0.027961750514805317 0.015856534708291292
# 0.02791643631644547 0.01592982839792967
# 0.027823404176160693 0.015740497270599008
# 0.02818656456656754 0.016620725626125932

# %%
  # # aug supervised
            # # chunks to average res
            # labels_augl_chunks = torch.reshape(
            #     labels_augl, 
            #     (L, int(labels_augl.shape[0]/L), labels_augl.shape[-1])
            
            # )
            # labels_augl_mean = labels_augl_chunks.mean(dim=0)
            # # calc upon true yl
            # loss_augl_true = unsupervised_loss(
            #     yl,
            #     labels_augl_chunks,
            #     yl.shape[0]
            # )
            # yaugl_true_loss = loss_augl_true.item()

            # # calc upon aug mean
            # loss_augl = unsupervised_loss(
            #     labels_augl_mean,
            #     labels_augl_chunks,
            #     labels_augl_mean.shape[0]
            # )
            # yaugl_loss = loss_augl.item()

            # # perfect case when it's around 0
            # loss_yaugl = torch.abs(
            #     (torch.abs(loss_augl_true) - torch.abs(loss_augl))
            # )
